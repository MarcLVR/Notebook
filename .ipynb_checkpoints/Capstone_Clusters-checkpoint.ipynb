# %% [markdown]
# # Economy of agglomeration on Business Clusters

# %% [markdown]
# ## Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction and Purpose](#introduction)
# * [Methodology](#methodology)
# * [Data](#data)
# * [Analysis](#analysis)
# * [Results](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction and Purpose <a name="introduction"></a>

# %% [markdown]
# All-round the world companies and small businesses are agglomerated in one district or around. This agglomeration contributes significatively to decreasing the price of production, deployment, as it does on creating a more innovative and productive environment for their employees. Many of these effects are widely known on business clusters and lately have shown amazing results on other sectors such as biotech, high-tech, and so on, having a great example on BioPharma clusters in Switzerland or HighTech ecosystems in other countries.
#
# The success of a company is not determined by the location of the office although it can affect directly, as clusters pretend to do. Knowing that this project is a beginner-intermediate one and the subject chosen is complex if it is studied in complete detail, the results will be shown as probable, without determining the rest of the factors that can affect the success in the location of your company or your services around a particular location. As the capstone project demands it will be using Foursquare API that we will get the data to find relations.
#
# The purpose of this project is to give possible solutions, in the location of the company, for these expecting to grow fast in a short time, in the same way, contribute to the proper location of services and franchises when you want them located in these clusters.
#
# I encourage anyone with knowledge and interest in this field to use my work and find out more about the relationship between business, biopharma, or startup clusters and their location and services around the same. I think that these models can be of remarkable interest for all the countries that are developing their clusters to do it successfully, particularly now, that we live a pharmaceutical revolution due to the current situation with Covid-19.

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# The stages from acquisition to deploy a solution have been the next:
#
# - Acquisition of Data trough Deloitte's PDF EMEA Fast Growth 2019 and the consequent cleaning.
# - Location of the address, latitude and longitude of the companies listes using GeoCode API of Google.
# - Mapping using floium the companies by the industry sector and cluster them with k-means.
# - Identify services around companies by sector using Foursquare API.
# - Analysing and visualizing the results.

# %%
import numpy as np
import sys
import seaborn as sns
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import csv
import pylab as pl
import urllib.parse
import folium
import json
import geojson
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
from folium.folium import Map
from sklearn.cluster import AgglomerativeClustering
from geopy.geocoders import Nominatim, GoogleV3      # convert an address into latitude and longitude values
from pandas.io.json import json_normalize            # tranform JSON file into a pandas dataframe
from sklearn.cluster import KMeans

# %matplotlib inline

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# ### Acquisition of Data

# %%
df = pd.read_csv("C:/Users/perez/Desktop/Notebook/gx-emea_fast_500_Ranking-2019.csv")
df.dropna(how='any', inplace = True)
df.drop(df.index[[25, 51, 77, 103, 129, 155, 181, 206, 230, 256, 282, 308, 334, 359, 384, 409, 435, 461, 486]], inplace = True)
df['Growth'] = df['Growth'].apply(lambda x: int(x.split("%")[0].replace(' ', '')))
df.rename(columns={'Growth': 'Growth %', 'Company name for communication': 'Company', 'Industry sector': 'Sector'})
df1 = df  #Saving the original DataFrame for other uses
df
# At this stage the dataframe has been cleaned of NaN's and other unuseful values
# Out:
#     Ranking Company name for communication    Country  Growth  \
# 0         1                        Revolut         UK   39754
# 1         2                       OakNorth         UK   30706
# 2         3   Cloud&Heat Technologies GmbH         DE   21474
# 3         4                      DivideBuy         UK   19572
# 4         5                        FINEWAY         DE   16594
# ..      ...                            ...        ...     ...
# 571     496                    shopware AG         DE     159
# 572     497            metacrew group GmbH         DE     159
# 573     498                         LESCAV    Belgium     158
# 574     499                     Paysera LT  Lithuania     158
# 575     500                   Arcus Global         UK     157
#
#               Industry sector
# 0                     Fintech
# 1                     Fintech
# 2    Environmental Technology
# 3                     Fintech
# 4                    Software
# ..                        ...
# 571                  Software
# 572   Media and Entertainment
# 573                  Hardware
# 574                   Fintech
# 575                  Software
#
# [493 rows x 5 columns]

# %% [markdown]
# ### UK DataFrame

# %%
#Code to inspect the data by sector and countries
df['Industry sector'].value_counts()
df['Country'].value_counts()

# I will choose UK as it is de country with more companies for the first analysis
df = df[df['Country'] == 'UK'] 
# I will work with these companies which are more than five in the same sector
df = df[df['Industry sector'] != 'Environmental Technology'] 
df = df[df['Industry sector'] != 'Communications']
df = df[df['Industry sector'] != 'Healthcare and Life Sciences']

df.head(10)
# Out:
#    Ranking Company name for communication Country  Growth  \
# 0        1                        Revolut      UK   39754
# 1        2                       OakNorth      UK   30706
# 3        4                      DivideBuy      UK   19572
# 11      12                        Moteefe      UK    7394
# 20      21                    Clearmatics      UK    4900
# 29      26                     ClearScore      UK    4382
# 33      30                       Lendable      UK    3883
# 43      40                       Privitar      UK    2797
# 49      46                         Onfido      UK    2324
# 63      56                         Paddle      UK    2013
#
#             Industry sector
# 0                   Fintech
# 1                   Fintech
# 3                   Fintech
# 11  Media and Entertainment
# 20                 Software
# 29                  Fintech
# 33                  Fintech
# 43                 Software
# 49                  Fintech
# 63                 Software

# %% [markdown]
# ### Netherlands DataFrame

# %%
# Using the original DataFrame we see NL as the second country with more companies on the list
df1['Country'].value_counts()
df1 = df1[df1['Country'] == 'NL']
# We will work with companyes with at least five times on the sector in the NL
df1['Industry sector'].value_counts()
df1 = df1[df1['Industry sector'] != 'Communications']
df1 = df1[df1['Industry sector'] != 'Healthcare and Life Sciences']
df1 = df1[df1['Industry sector'] != 'Fintech']
df1 = df1[df1['Industry sector'] != 'Hardware']
df1.head(20)
# Out:
#     Ranking Company name for communication Country  Growth  \
# 9        10         Flightgift / Hotelgift      NL    7628
# 16       17                   Mews Systems      NL    5384
# 21       22                       PastBook      NL    4623
# 39       36                     Simplicate      NL    3013
# 81       74                      Channable      NL    1791
# 104      93                Scrambled Group      NL    1458
# 117     102                        Appwiki      NL    1281
# 122     107                        3D Hubs      NL    1258
# 126     111                         Parkos      NL    1234
# 134     119                         POSTEX      NL    1164
# 135     120                   Team Nijhuis      NL    1156
# 139     124                  APOC Aviation      NL    1088
# 155     136               The Inner Circle      NL     963
# 178     155                     Zelfstroom      NL     895
# 187     164                      SendCloud      NL     856
# 211     184                        Cloud++      NL     769
# 213     186                      Studytube      NL     755
# 253     222              Stars and Stories      NL     654
# 270     235                          Mapiq      NL     597
# 272     237                     SecureLink      NL     588
#
#               Industry sector
# 9                    Software
# 16                   Software
# 21    Media and Entertainment
# 39                   Software
# 81                   Software
# 104   Media and Entertainment
# 117   Media and Entertainment
# 122                  Software
# 126                  Software
# 134                  Software
# 135   Media and Entertainment
# 139                  Software
# 155   Media and Entertainment
# 178  Environmental Technology
# 187  Environmental Technology
# 211                  Software
# 213                  Software
# 253   Media and Entertainment
# 270                  Software
# 272                  Software

# %% [markdown]
# ### Geolocation of UK Companies

# %%
#Set instructions to use Google API
base_url= "https://maps.googleapis.com/maps/api/geocode/json?"
AUTH_KEY = "***************************"
geolocator = GoogleV3(api_key = AUTH_KEY)

components = [ ('country', 'GB' )]
def get_location(x):
    return geolocator.geocode(x, components=components)

df["loc"] = df["Company name for communication"].apply(get_location)
df["point"]= df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)
df[['lat', 'lon', 'altitude']] = pd.DataFrame(df['point'].to_list(), index=df.index)
## Adding manually the information that has not been reached by the API
df.loc[43,'loc'] = '(15 Hatfields, South Bank, London SE1 8DJ, United Kingdom)'
df.loc[43,'point'] = '(51.506855, -0.107148)'
df.loc[43,'lat'] = 51.50685
df.loc[43,'lon'] = -0.10714
df.loc[43,'altitude'] = '0'
df.loc[72,'loc'] = '(Brunel Way, Catcliffe, Rotherham S60 5WG, United Kingdom)'
df.loc[72,'point'] = '(53.386183, -1.378254)'
df.loc[72,'lat'] = 53.38618
df.loc[72,'lon'] = -1.378254
df.loc[72,'altitude'] = '0'
df.loc[121,'loc'] = '(175 Glasgow Rd, Edinburgh EH12 9SB, United Kingdom)'
df.loc[121,'point'] = '(55.934881, -3.334630)'
df.loc[121,'lat'] = 55.93488
df.loc[121,'lon'] = -3.33463
df.loc[121,'altitude'] = '0'
df.loc[214,'loc'] = '(49 Jamaica St, Liverpool L1 0AH, United Kingdom)'
df.loc[214,'point'] = '(53.395409, -2.980149)'
df.loc[214,'lat'] = 53.3954
df.loc[214,'lon'] = -2.98014
df.loc[214,'altitude'] = '0'
df.loc[326,'loc'] = '(1st Floor, 99 Clifton Street, London EC2A 4LG)'
df.loc[326,'point'] = '(51.522996, -0.083417)'
df.loc[326,'lat'] = 51.52299
df.loc[326,'lon'] = -0.08341
df.loc[326,'altitude'] = '0'
df.loc[395,'loc'] = '(25 Greenside Pl, Edinburgh EH1 3AA, United Kingdom)'
df.loc[395,'point'] = '(55.957294, -3.185021)'
df.loc[395,'lat'] = 55.95729
df.loc[395,'lon'] = -3.18502
df.loc[395,'altitude'] = '0'
df.loc[435,'loc'] = '(5th Floor, House, 52, 54 High Holborn, Holborn, London WC1V 6RL, United Kingdom)'
df.loc[435,'point'] = '(51.518419, -0.115012)'
df.loc[435,'lat'] = 51.51841
df.loc[435,'lon'] = -0.11501
df.loc[435,'altitude'] = '0'
df.loc[450,'loc'] = '(Screenworks Building, London N5 2EF, United Kingdom)'
df.loc[450,'point'] = '(51.550740, -0.097063)'
df.loc[450,'lat'] = 51.55074
df.loc[450,'lon'] = -0.09706
df.loc[450,'altitude'] = '0'
df.loc[480,'loc'] = '(5 Langley St, Covent Garden, London WC2H 9JA, United Kingdom)'
df.loc[480,'point'] = '(51.513187, -0.124933)'
df.loc[480,'lat'] = 51.51318
df.loc[480,'lon'] = -0.12493
df.loc[480,'altitude'] = '0'
df.loc[530,'loc'] = '(25 Wilton Road, Victoria, London, UK)'
df.loc[530,'point'] = '(51.495242, -0.142358)'
df.loc[530,'lat'] = 51.49524
df.loc[530,'lon'] = -0.14235
df.loc[530,'altitude'] = '0'

# %%
df.drop(columns=['altitude'])
# Out:
#     Ranking Company name for communication Country  Growth  \
# 0         1                        Revolut      UK   39754
# 1         2                       OakNorth      UK   30706
# 3         4                      DivideBuy      UK   19572
# 11       12                        Moteefe      UK    7394
# 20       21                    Clearmatics      UK    4900
# ..      ...                            ...     ...     ...
# 541     470                     Cloudhouse      UK     183
# 543     472                          Zappi      UK     180
# 565     490                       disguise      UK     162
# 568     493                    Purple WiFi      UK     161
# 575     500                   Arcus Global      UK     157
#
#              Industry sector  \
# 0                    Fintech
# 1                    Fintech
# 3                    Fintech
# 11   Media and Entertainment
# 20                  Software
# ..                       ...
# 541                 Software
# 543                 Software
# 565                 Software
# 568                 Software
# 575                 Software
#
#                                                    loc  \
# 0    (7 Westferry Circus, Canary Wharf, London E14 ...
# 1    (6th Floor, Nightingale House, 65 Curzon St, M...
# 3    (First Floor, Brunswick Court, Brunswick St, N...
# 11   (84 Eccleston Square, Pimlico, London SW1V 1NP...
# 20   (30 City Rd, London EC1Y 2AY, UK, (51.5226132,...
# ..                                                 ...
# 541  (Ugli Campus Block A, 56 Wood Ln, Shepherd's B...
# 543  (Theatre House, 97 - 99 Camden High St, London...
# 565  (88-89 Blackfriars Rd, South Bank, London SE1 ...
# 568  (Meadowbank House, Tweedale Way, Chadderton, O...
# 575  (Future Business Centre, Kings Hedges Rd, Camb...
#
#                                        point        lat       lon
# 0              (51.5062984, -0.0258565, 0.0)  51.506298 -0.025857
# 1               (51.507971, -0.1447259, 0.0)  51.507971 -0.144726
# 3              (53.0124212, -2.2207889, 0.0)  53.012421 -2.220789
# 11             (51.4931108, -0.1435609, 0.0)  51.493111 -0.143561
# 20   (51.5226132, -0.08738939999999999, 0.0)  51.522613 -0.087389
# ..                                       ...        ...       ...
# 541             (51.511679, -0.2235788, 0.0)  51.511679 -0.223579
# 543             (51.536677, -0.1409407, 0.0)  51.536677 -0.140941
# 565            (51.5026301, -0.1048307, 0.0)  51.502630 -0.104831
# 568            (53.5187596, -2.1525585, 0.0)  53.518760 -2.152559
# 575               (52.234851, 0.129525, 0.0)  52.234851  0.129525
#
# [91 rows x 9 columns]

# %%
df.point.isna().sum()
df.dropna(subset=['point'], inplace=True)

# %% [markdown]
# ### Geolocation of Netherlands Companies

# %%
#Set instructions to use Google API
base_url= "https://maps.googleapis.com/maps/api/geocode/json?"
AUTH_KEY = "*********************"
geolocator = GoogleV3(api_key = AUTH_KEY)

components = [ ('country', 'NL' )]
def get_location(x):
    return geolocator.geocode(x, components=components)

df1["loc"] = df1["Company name for communication"].apply(get_location)
df1["point"]= df1["loc"].apply(lambda loc: tuple(loc.point) if loc else None)
df1[['lat', 'lon', 'altitude']] = pd.DataFrame(df1['point'].to_list(), index=df1.index)
df1.loc[211,'loc'] = '(Kruisstraat 5, 8501 BP Joure, Netherlands)'
df1.loc[211,'point'] = '(52.969678, 5.793303)'
df1.loc[211,'lat'] = 52.969678
df1.loc[211,'lon'] = 5.793303
df1.drop(columns=['altitude'])
# Out:
#     Ranking Company name for communication Country  Growth  \
# 9        10         Flightgift / Hotelgift      NL    7628
# 16       17                   Mews Systems      NL    5384
# 21       22                       PastBook      NL    4623
# 39       36                     Simplicate      NL    3013
# 81       74                      Channable      NL    1791
# ..      ...                            ...     ...     ...
# 532     461                       FiscFree      NL     189
# 538     467                      FindHotel      NL     185
# 544     473                    SpriteCloud      NL     177
# 560     485      Intus Workforce Solutions      NL     167
# 567     492                 Pimm Solutions      NL     162
#
#              Industry sector  \
# 9                   Software
# 16                  Software
# 21   Media and Entertainment
# 39                  Software
# 81                  Software
# ..                       ...
# 532                 Software
# 538                 Software
# 544                 Software
# 560                 Software
# 567                 Software
#
#                                                    loc  \
# 9    (Herengracht 493-1, 1017 BT Amsterdam, Netherl...
# 16   (Wibautstraat 137D, 1097 DN Amsterdam, Netherl...
# 21   (A'dam Tower, Overhoeksplein 3, 1031 KS Amster...
# 39   (Laan Corpus Den Hoorn 102-1, 9728 JR Groninge...
# 81   (Drift 17, 3512 BR Utrecht, Netherlands, (52.0...
# ..                                                 ...
# 532  (Industrieweg 8, 8444 AS Heerenveen, Netherlan...
# 538  (Nieuwe Looiersdwarsstraat 9, 1017 TZ Amsterda...
# 544  (Generaal Vetterstraat 72b, 1059 BW Amsterdam,...
# 560  (Princenhofpark 12, 3972 NG Driebergen-Rijsenb...
# 567  (Westblaak 180, 3012 KN Rotterdam, Netherlands...
#
#                                            point        lat       lon
# 9           (52.3656455, 4.891122500000001, 0.0)  52.365645  4.891123
# 16          (52.3495268, 4.917836599999999, 0.0)  52.349527  4.917837
# 21                  (52.3839175, 4.9024846, 0.0)  52.383918  4.902485
# 39                  (53.1937232, 6.5536278, 0.0)  53.193723  6.553628
# 81                  (52.0937575, 5.1234962, 0.0)  52.093758  5.123496
# ..                                           ...        ...       ...
# 532                 (52.9330068, 5.9484542, 0.0)  52.933007  5.948454
# 538                 (52.3609399, 4.8938269, 0.0)  52.360940  4.893827
# 544          (52.343881, 4.846613899999999, 0.0)  52.343881  4.846614
# 560  (52.06571109999999, 5.258610399999999, 0.0)  52.065711  5.258610
# 567                  (51.9163212, 4.475754, 0.0)  51.916321  4.475754
#
# [64 rows x 9 columns]

# %%
df1.point.isna().sum()
df1.dropna(subset=['point'], inplace=True)
# Out:
# Software                    42
# Media and Entertainment     12
# Environmental Technology     5
# Name: Industry sector, dtype: int64

# %% [markdown]
# ### Mapping Netherlands Companies by sector

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## Now that we can see the map we can delete the outlier companies 
df1 = df1[df1['Company name for communication'] != 'Grizzly New Marketing']
df1 = df1[df1['Company name for communication'] != 'Cloud++']
df1 = df1[df1['Company name for communication'] != 'FiscFree']
df1 = df1[df1['Company name for communication'] != 'Stars and Stories']
x = list(zip(df1['lon'].values, df1['lat'].values))
## We can use the agglomerativeclustering to locate the claster easily
clustering = AgglomerativeClustering(7).fit(x)
clustering.labels_
df1['cluster'] = clustering.labels_
df1

# %%
# We find the centroid of the cluster located in amsterdam in this case
k_means = KMeans(init="k-means++", n_clusters=7, n_init=25)
k_means.fit(x)
k_means_labels = k_means.labels_
k_means_cluster_centers = k_means.cluster_centers_
k_means_cluster_centers
latitudea = 52.37593
longitudea = 4.86973752

# %%
# Map for Netherlands
lat_nl = 52.132633 
long_nl =  5.291266
map_nl = folium.Map(location=[lat_nl, long_nl], zoom_start=7)

##colordict = {'Software': 'blue', 'Media and Entertainment': 'green', 'Environmental Technology': 'white'}
colordict = {0: 'blue', 1: 'green', 2: 'yellow', 3: 'red', 4: 'white', 5: 'orange', 6: 'grey'}

# add markers to map
for lat, lng, label, sector in zip(df1['lat'], df1['lon'], df1['Company name for communication'], df1['cluster']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label, 
        color='black',
        fill=True,
        fill_color=colordict[sector],
        fill_opacity=0.7,
        parse_html=False).add_to(map_nl)    
map_nl
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Mapping UK Companies by sector

# %%
## Now that we can see the map we can delete the outlier companies 
df = df[df['Company name for communication'] != 'DJS (UK) Limited']
df = df[df['Company name for communication'] != 'MPB Group Limited']
df = df[df['Company name for communication'] != 'Vizolution']
df = df[df['Company name for communication'] != 'Unify Communications Ltd.']
df = df[df['Company name for communication'] != 'Hutch']
df = df[df['Company name for communication'] != 'Person Centred Software']
df = df[df['Company name for communication'] != 'Peak']
df = df[df['Company name for communication'] != 'Bango']
df = df[df['Company name for communication'] != 'Giacom']
df = df[df['Company name for communication'] != 'SimplyCook']
df = df[df['Company name for communication'] != 'Cloudhouse']

# %%
x = list(zip(df['lon'].values, df['lat'].values))
clustering = AgglomerativeClustering(6).fit(x)
clustering
clustering.labels_
df['cluster'] = clustering.labels_
k_means = KMeans(init="k-means++", n_clusters=6, n_init=25)
k_means.fit(x)
k_means_labels = k_means.labels_
k_means_cluster_centers = k_means.cluster_centers_
k_means_cluster_centers
# Out:
# array([[-2.27808046, 53.27659971],
#        [-0.10712727, 51.51475156],
#        [-3.49757842, 55.92589423],
#        [-1.38091464, 53.38485667],
#        [-1.23098717, 51.6165441 ],
#        [ 0.1373794 , 52.23578662]])

# %%
# We get de coordinates of the cluster of London and Cambridge
k_means_cluster_centers = k_means.cluster_centers_
centroids = pd.DataFrame(k_means_cluster_centers)
latitude = 51.51470127
longitude = -0.10633714
latitudec = 52.23578662
longitudec = 0.1373794

# %%
lat_gb = 54.378051 
long_gb = -3.435973
map_gb = folium.Map(location=[lat_gb, long_gb], zoom_start=6)

colordict = {0: 'blue', 1: 'green', 2: 'yellow', 3: 'red', 4: 'white', 5: 'orange'}
###colordict = {'Software': 'blue', 'Media and Entertainment': 'green', 'Fintech': 'white', 'Hardware': 'red'}

with open('C:/Users/perez/london_boroughs.json') as json_data:
    london = json.load(json_data)
    
folium.GeoJson(
    london,
    name='geojson'
).add_to(map_gb)

# add markers to map
for lat, lng, label, sector in zip(df['lat'], df['lon'], df['Company name for communication'], df['cluster']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label, 
        color='black',
        fill=True,
        fill_color=colordict[sector],
        fill_opacity=0.7,
        parse_html=False).add_to(map_gb)    
map_gb
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Foursquare API - UK

# %%
CLIENT_ID = '*************************************' # your Foursquare ID
CLIENT_SECRET = '**********************************' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 40
search_query = 'College & University' ##Nightlife Spot Outdoors & Recreation Shop & Service Travel & Transport Arts & Entertainment
radius = 2000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()

# assign relevant part of JSON to venues
venues = results['response']['venues']

# %%
CLIENT_ID = 'UXH3QXWSKIKRCISLRKVKEGCO54GYL3RWVPU3FZ4HCBVDUOBN' # your Foursquare ID
CLIENT_SECRET = 'TSCQVX0CDVXZNLTEQW5X2LHUXQE53A2DRRJ22NJR54RKYHAY' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
search_query = 'College & University' ##Nightlife Spot Outdoors & Recreation Shop & Service Travel & Transport Arts & Entertainment
radius = 2000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitudec, longitudec, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()

# assign relevant part of JSON to venues
venuesc = results['response']['venues']

# %%
# tranform venues into a dataframe
dataframe = pd.json_normalize(venues)
dataframe.head()

# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered
# Out:
#                                                  name  \
# 0                         Kings College Student Union
# 1                Royal College of Surgeons of England
# 2                 Royal College Of Emergency Medicine
# 3             King's College London - Waterloo Campus
# 4               King's College London - Strand Campus
# 5           King's College - Language Resource Center
# 6                                  Kensington College
# 7                           University College London
# 8      LonDEC, King's College London Dental Institute
# 9                         University College Hospital
# 10                                       College Hall
# 11        King's College London - Drury Lane Building
# 12                                    Princes College
# 13                                 Goodenough College
# 14                                       Cats College
# 15                              Shakespearean College
# 16                              Global College London
# 17                          Eynsford Language College
# 18                    CCL (College of Central London)
# 19                          College Of Medicine - KSU
# 20                                    College Heights
# 21  MRC Laboartory for Molecular Cell Biology, Uni...
# 22                                    College of Arms
# 23                                   Williams College
# 24  King’s College London - Bush House North East ...
# 25                                    Gresham College
# 26                 London College Of Contemporary Art
# 27                    The College, 12 Southampton Row
# 28                Kaplan International College London
# 29                    London College of Communication
# 30                      College Of Emergency Medicine
# 31                 King's College London - Bush House
# 32                          King's College Law School
# 33         King's College London Sports & Social Club
# 34                     Library Royal College Surgeons
# 35  Centre For Telecommunications Research-king's ...
# 36                        st patricks college holborn
# 37                        cafe direct @ kings college
# 38                                     College of law
# 39       S2.31, King’s College London (Strand Campus)
#
#                                   categories  \
# 0                             Student Center
# 1                             Medical School
# 2            College Administrative Building
# 3                                 University
# 4                                 University
# 5                      College Arts Building
# 6            College Administrative Building
# 7                                 University
# 8                             Medical School
# 9                                   Hospital
# 10                    College Residence Hall
# 11                                University
# 12                                    Office
# 13                            Student Center
# 14                 College Academic Building
# 15              General College & University
# 16                 College Academic Building
# 17              General College & University
# 18              General College & University
# 19                            Medical School
# 20  Residential Building (Apartment / Condo)
# 21                               Medical Lab
# 22                       Monument / Landmark
# 23                 College Academic Building
# 24                 College Academic Building
# 25                                University
# 26              General College & University
# 27                 College Academic Building
# 28              General College & University
# 29                     College Arts Building
# 30                            Medical School
# 31               College Technology Building
# 32                                Law School
# 33                               Social Club
# 34                           College Library
# 35                 College Academic Building
# 36                 College Academic Building
# 37                                      Café
# 38                                Law School
# 39                         College Classroom
#
#                                              address        lat       lng  \
# 0                                         Surrey St.  51.511180 -0.115169
# 1                         35-43 Lincoln's Inn Fields  51.515371 -0.116231
# 2                              7-9 Bream's Buildings  51.516114 -0.111225
# 3                                        Stamford St  51.505598 -0.112166
# 4                                             Strand  51.511627 -0.116376
# 5                                                NaN  51.511255 -0.115696
# 6                            Wesley Ho, 4 Wild Court  51.515536 -0.119353
# 7                                           Gower St  51.524395 -0.133593
# 8                3rd Floor Franklin Wilkins Building  51.505456 -0.112899
# 9                                    235 Euston Road  51.525004 -0.136339
# 10                                         Malet St.  51.522250 -0.131133
# 11                                  26-29 Drury Lane  51.514786 -0.123150
# 12                              36 New Oxford Street  51.517160 -0.125418
# 13                                  Mecklenburgh Sq.  51.526110 -0.118912
# 14                              43-45 Bloomsbury Sq.  51.518405 -0.121875
# 15                                     34 Bloomsbury  51.518298 -0.127844
# 16                                               NaN  51.514248 -0.107477
# 17                                             37-39  51.516189 -0.131796
# 18                                               NaN  51.527130 -0.086530
# 19                                               NaN  51.512803 -0.100416
# 20  College Heights, 246-252 St John St, Clerkenwell  51.525951 -0.103056
# 21                                      Gower Street  51.524280 -0.131795
# 22                         130 Queen Victoria Street  51.512007 -0.098475
# 23                                               NaN  51.517145 -0.105095
# 24                                           Aldwych  51.513034 -0.116899
# 25                                Barnard's Inn Hall  51.517685 -0.109794
# 26                                               NaN  51.518055 -0.110587
# 27                                               NaN  51.518927 -0.121084
# 28                                      Palace House  51.532738 -0.107333
# 29                            UAL, Elephant & Castle  51.494837 -0.101476
# 30                                               NaN  51.519280 -0.119321
# 31                                               NaN  51.512600 -0.116931
# 32                             Strand Somerset House  51.511308 -0.117140
# 33                                               NaN  51.511838 -0.115820
# 34                                               NaN  51.514588 -0.116091
# 35                                               NaN  51.511780 -0.115796
# 36                                               NaN  51.515123 -0.114950
# 37                                               NaN  51.511284 -0.115904
# 38                                         2 bunhill  51.521508 -0.089436
# 39                                               NaN  51.511625 -0.116003
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 51.51117983551853...       726   WC2R 2LS
# 1   [{'label': 'display', 'lat': 51.51537097576288...       689   WC2A 3PE
# 2   [{'label': 'display', 'lat': 51.5161143873048,...       373   EC4A 1DT
# 3   [{'label': 'display', 'lat': 51.50559751070975...      1090        SE1
# 4   [{'label': 'display', 'lat': 51.5116270804117,...       775   WC2R 2LS
# 5   [{'label': 'display', 'lat': 51.511255, 'lng':...       753        NaN
# 6   [{'label': 'display', 'lat': 51.51553585857806...       906   WC2B 4AU
# 7   [{'label': 'display', 'lat': 51.52439526888408...      2174   WC1E 6BT
# 8   [{'label': 'display', 'lat': 51.50545575971391...      1125    SE1 9NH
# 9   [{'label': 'display', 'lat': 51.52500442254615...      2373    NW1 2BU
# 10  [{'label': 'display', 'lat': 51.52224975605932...      1912   WC1E 7HZ
# 11  [{'label': 'display', 'lat': 51.5147855725507,...      1164   WC2B 5RL
# 12  [{'label': 'display', 'lat': 51.51715977380225...      1349   WC1A 1EP
# 13  [{'label': 'display', 'lat': 51.52611049009676...      1540   WC1N 2AN
# 14  [{'label': 'display', 'lat': 51.51840492661380...      1152   WC1A 2RA
# 15  [{'label': 'display', 'lat': 51.51829804463054...      1542        NaN
# 16  [{'label': 'display', 'lat': 51.51424765129443...        93        NaN
# 17  [{'label': 'display', 'lat': 51.51618893787597...      1771        NaN
# 18  [{'label': 'display', 'lat': 51.52712964078540...      1948        NaN
# 19  [{'label': 'display', 'lat': 51.512803, 'lng':...       461        NaN
# 20  [{'label': 'display', 'lat': 51.52595068756537...      1272   EC1V 4PH
# 21  [{'label': 'display', 'lat': 51.52427960215237...      2060   WC1E 6BT
# 22  [{'label': 'display', 'lat': 51.51200696300692...       621   EC4V 4BT
# 23  [{'label': 'display', 'lat': 51.51714465968388...       285        NaN
# 24  [{'label': 'display', 'lat': 51.513034, 'lng':...       754   WC2B 4BG
# 25  [{'label': 'display', 'lat': 51.5176848146853,...       409   EC1N 2HH
# 26  [{'label': 'display', 'lat': 51.518055, 'lng':...       475   EC1N 2LL
# 27  [{'label': 'display', 'lat': 51.518927, 'lng':...      1124      W C1B
# 28  [{'label': 'display', 'lat': 51.53273828651154...      2009    SE1 9DE
# 29  [{'label': 'display', 'lat': 51.49483667136030...      2236    SE1 6SB
# 30  [{'label': 'display', 'lat': 51.5192804875453,...      1033        NaN
# 31  [{'label': 'display', 'lat': 51.51260002394812...       770        NaN
# 32  [{'label': 'display', 'lat': 51.51130794610128...       838        NaN
# 33  [{'label': 'display', 'lat': 51.51183771232248...       730        NaN
# 34  [{'label': 'display', 'lat': 51.514588, 'lng':...       675        NaN
# 35  [{'label': 'display', 'lat': 51.51178, 'lng': ...       731        NaN
# 36  [{'label': 'display', 'lat': 51.51512322025362...       598        NaN
# 37  [{'label': 'display', 'lat': 51.5112837912044,...       764        NaN
# 38  [{'label': 'display', 'lat': 51.521508, 'lng':...      1394        NaN
# 39  [{'label': 'display', 'lat': 51.511625, 'lng':...       752   WC2R 2NA
#
#     cc         city           state         country  \
# 0   GB       London  Greater London  United Kingdom
# 1   GB      Holborn  Greater London  United Kingdom
# 2   GB       London  Greater London  United Kingdom
# 3   GB       London  Greater London  United Kingdom
# 4   GB       London  Greater London  United Kingdom
# 5   GB          NaN             NaN  United Kingdom
# 6   GB       London  Greater London  United Kingdom
# 7   GB       London  Greater London  United Kingdom
# 8   GB     Waterloo  Greater London  United Kingdom
# 9   GB  Camden Town  Greater London  United Kingdom
# 10  GB  Camden Town  Greater London  United Kingdom
# 11  GB       London  Greater London  United Kingdom
# 12  GB       London  Greater London  United Kingdom
# 13  GB       London  Greater London  United Kingdom
# 14  GB       London  Greater London  United Kingdom
# 15  GB       London  Greater London  United Kingdom
# 16  GB          NaN             NaN  United Kingdom
# 17  GB       London  Greater London  United Kingdom
# 18  GB       Лондон             NaN  United Kingdom
# 19  GB          NaN             NaN  United Kingdom
# 20  GB       London  Greater London  United Kingdom
# 21  GB       London  Greater London  United Kingdom
# 22  GB       London  Greater London  United Kingdom
# 23  GB       London  Greater London  United Kingdom
# 24  GB       London  Greater London  United Kingdom
# 25  GB       London  Greater London  United Kingdom
# 26  GB          NaN             NaN  United Kingdom
# 27  GB       London  Greater London  United Kingdom
# 28  GB       London  Greater London  United Kingdom
# 29  GB       London  Greater London  United Kingdom
# 30  GB          NaN             NaN  United Kingdom
# 31  GB          NaN             NaN  United Kingdom
# 32  GB          NaN             NaN  United Kingdom
# 33  GB          NaN             NaN  United Kingdom
# 34  GB          NaN             NaN  United Kingdom
# 35  GB          NaN             NaN  United Kingdom
# 36  GB          NaN             NaN  United Kingdom
# 37  GB          NaN             NaN  United Kingdom
# 38  GB    Islington  Greater London  United Kingdom
# 39  GB       London  Greater London  United Kingdom
#
#                                      formattedAddress  \
# 0   [Surrey St., London, Greater London, WC2R 2LS,...
# 1   [35-43 Lincoln's Inn Fields, Holborn, Greater ...
# 2   [7-9 Bream's Buildings, London, Greater London...
# 3   [Stamford St, London, Greater London,  SE1, Un...
# 4   [Strand (at Surrey St), London, Greater London...
# 5                                    [United Kingdom]
# 6   [Wesley Ho, 4 Wild Court, London, Greater Lond...
# 7   [Gower St (btwn Gower Pl. & Torrington Pl.), L...
# 8   [3rd Floor Franklin Wilkins Building (150 Stam...
# 9   [235 Euston Road (Gower St), Camden Town, Grea...
# 10  [Malet St., Camden Town, Greater London, WC1E ...
# 11  [26-29 Drury Lane (Strand Campus), London, Gre...
# 12  [36 New Oxford Street, London, Greater London,...
# 13  [Mecklenburgh Sq., London, Greater London, WC1...
# 14  [43-45 Bloomsbury Sq., London, Greater London,...
# 15  [34 Bloomsbury, London, Greater London, United...
# 16                                   [United Kingdom]
# 17  [37-39 (Oxford St.), London, Greater London, U...
# 18                           [Лондон, United Kingdom]
# 19                                   [United Kingdom]
# 20  [College Heights, 246-252 St John St, Clerkenw...
# 21  [Gower Street, Camden, Greater London, WC1E 6B...
# 22  [130 Queen Victoria Street, London, Greater Lo...
# 23           [London, Greater London, United Kingdom]
# 24  [Aldwych, London, Greater London, WC2B 4BG, Un...
# 25  [Barnard's Inn Hall (btwn Fetter Ln. and Furni...
# 26                         [EC1N 2LL, United Kingdom]
# 27    [London, Greater London, W C1B, United Kingdom]
# 28  [Palace House (3 Cathedral Street), London, Gr...
# 29  [UAL, Elephant & Castle, London, Greater Londo...
# 30                                   [United Kingdom]
# 31                                   [United Kingdom]
# 32            [Strand Somerset House, United Kingdom]
# 33                                   [United Kingdom]
# 34                                   [United Kingdom]
# 35                                   [United Kingdom]
# 36                                   [United Kingdom]
# 37                                   [United Kingdom]
# 38  [2 bunhill, Islington, Greater London, United ...
# 39  [London, Greater London, WC2R 2NA, United King...
#
#                          crossStreet    neighborhood                        id
# 0                                NaN             NaN  4bfd26f883bbd13a98ed62c5
# 1                                NaN             NaN  4c39e0173849c928c7ebc1b1
# 2                                NaN             NaN  4e32882a62e12985fd629203
# 3                                NaN             NaN  4d2351912eb1f04d5c3e07c2
# 4                       at Surrey St             NaN  4b72fb14f964a520ae932de3
# 5                                NaN             NaN  56af76d438faae8405754445
# 6                                NaN             NaN  4d66271b84f28cfa13b36769
# 7    btwn Gower Pl. & Torrington Pl.             NaN  4b0a52daf964a5203e2323e3
# 8                    150 Stamford St             NaN  4d7b45026152b60c6c8f7b26
# 9                           Gower St             NaN  4bfb839cab180f479befb3ce
# 10                               NaN             NaN  4c2af66057a9c9b6db3ff567
# 11                     Strand Campus             NaN  4cd2a68625ee6dcbb034450f
# 12                               NaN             NaN  4f0d6a8ee4b0e190ab6ac78c
# 13                               NaN             NaN  4b3f1bfaf964a52012a425e3
# 14                               NaN             NaN  4e707015a8098087a01782f8
# 15                               NaN             NaN  5211f5b011d2775a7df60538
# 16                               NaN             NaN  4f9566fbe4b0b65a8c872028
# 17                        Oxford St.             NaN  516556b0e4b068ba321da8a1
# 18                               NaN             NaN  4ec4e9c18b812a2064cba79a
# 19                               NaN             NaN  534a32bf498e8d936002f2c5
# 20                               NaN             NaN  5c031182d552c7002c620d1c
# 21                               NaN             NaN  4d8d22e3b46488bfdafdc5a2
# 22                               NaN  City of London  4ac518d0f964a520b5a620e3
# 23                               NaN             NaN  4e08b79ed4c03ae0b9d16f5b
# 24                               NaN             NaN  5a65e791da5ede79a3dd4241
# 25  btwn Fetter Ln. and Furnival St.             NaN  4c18df22fe5a76b033a60215
# 26                               NaN             NaN  5dce75384725c60008380f35
# 27                               NaN             NaN  5be5c8fc67af3a0039b418bb
# 28                3 Cathedral Street      Bermondsey  4c32e68b213c2d7fbe1f365d
# 29                               NaN             NaN  4b62a4e8f964a520bb4d2ae3
# 30                               NaN             NaN  4cd7c38ea423a35dd74ce842
# 31                               NaN             NaN  56a64089498ee1e85dc5c194
# 32                               NaN             NaN  506ac436e4b07f06b10193ff
# 33                               NaN             NaN  52964f4511d2ee06ea92d8e4
# 34                               NaN             NaN  54ec8606498e2e9b20fd7e8f
# 35                               NaN             NaN  4d7e1340ebc15481772bdba6
# 36                               NaN             NaN  516e660ee4b042332ac4ad24
# 37                               NaN             NaN  5138babbe4b0e0ccc3762214
# 38                               NaN             NaN  4c0ca24198102d7fd5fbe006
# 39                               NaN             NaN  5a3010d73ba767094574635f

# %%
# tranform venues into a dataframe
dataframe = pd.json_normalize(venuesc)
dataframe.head()

# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filteredc = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filteredc['categories'] = dataframe_filteredc.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filteredc.columns = [column.split('.')[-1] for column in dataframe_filteredc.columns]
dataframe_filteredc
# Out:
#                                        name                    categories  \
# 0  Cambridge Regional College Sports Centre          Gym / Fitness Center
# 1          LRC @ Cambridge Regional College               College Library
# 2          Cambridge Regional College (CRC)                  Trade School
# 3                       College fields park                          Park
# 4          Bellerbys College Campus Library                       Library
# 5              Chesterton Community College             Community College
# 6                 Impington Village College  General College & University
# 7                Christ's College Boathouse          Gym / Fitness Center
#
#          lat       lng                                     labeledLatLngs  \
# 0  52.234847  0.135380  [{'label': 'display', 'lat': 52.23484676090613...
# 1  52.235321  0.134482  [{'label': 'display', 'lat': 52.235321484912, ...
# 2  52.235356  0.133982  [{'label': 'display', 'lat': 52.23535619082742...
# 3  52.225881  0.136987  [{'label': 'display', 'lat': 52.22588075994904...
# 4  52.225874  0.129697  [{'label': 'display', 'lat': 52.225874, 'lng':...
# 5  52.217615  0.122328  [{'label': 'display', 'lat': 52.21761492302305...
# 6  52.247581  0.116579  [{'label': 'display', 'lat': 52.24758057245346...
# 7  52.213687  0.125596  [{'label': 'display', 'lat': 52.213687, 'lng':...
#
#    distance  cc         country  \
# 0       171  GB  United Kingdom
# 1       204  GB  United Kingdom
# 2       236  GB  United Kingdom
# 3      1103  GB  United Kingdom
# 4      1221  GB  United Kingdom
# 5      2268  GB  United Kingdom
# 6      1932  GB  United Kingdom
# 7      2587  GB  United Kingdom
#
#                                     formattedAddress            address  \
# 0                                   [United Kingdom]                NaN
# 1                                   [United Kingdom]                NaN
# 2  [Kings Hedges Road, Cambridge, Cambridgeshire,...  Kings Hedges Road
# 3                                   [United Kingdom]                NaN
# 4        [Cambridge, Cambridgeshire, United Kingdom]                NaN
# 5  [79 Bateson Rd, Cambridge, Cambridgeshire, CB4...      79 Bateson Rd
# 6  [New Lane, Impington, Cambridgeshire, United K...           New Lane
# 7                                   [United Kingdom]                NaN
#
#         city           state postalCode                        id
# 0        NaN             NaN        NaN  4d93283f9213b1f72551c146
# 1        NaN             NaN        NaN  506ac419e4b014fb398a5e12
# 2  Cambridge  Cambridgeshire        NaN  4c0fca61b93cc9b61cb155e0
# 3        NaN             NaN        NaN  4fc126cde4b0117b73825586
# 4  Cambridge  Cambridgeshire        NaN  4eb3f70ae5fa17fc861cf763
# 5  Cambridge  Cambridgeshire    CB4 3YN  4e6e728e2271a8cac03aea5b
# 6  Impington  Cambridgeshire        NaN  4bf55627cad2c928bee59c99
# 7        NaN             NaN        NaN  514a13dae4b0a74cdde8bba4

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the centroid of the London cluster

# add a red circle marker to represent the London centroid
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='London Centroid',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Colleges & Universities as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
venues_map = folium.Map(location=[latitudec, longitudec], zoom_start=13) # generate map centred around the centroid of the Cambridge cluster

# add a red circle marker to represent the Cambridge centroid
folium.features.CircleMarker(
    [latitudec, longitudec],
    radius=10,
    color='green',
    popup='Cambridge Centroid',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Colleges & Universities as blue circle markers
for lat, lng, label in zip(dataframe_filteredc.lat, dataframe_filteredc.lng, dataframe_filteredc.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Foursquare API - Netherlands

# %%
CLIENT_ID = '**************************' # your Foursquare ID
CLIENT_SECRET = '**************************' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
search_query = 'College & University' ##Nightlife Spot Outdoors & Recreation Shop & Service Travel & Transport Arts & Entertainment
radius = 2000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitudea, longitudea, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitudea, longitudea, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()
# assign relevant part of JSON to venues
venuesa = results['response']['venues']

# %%
# tranform venues into a dataframe
dataframe = pd.json_normalize(venuesa)
dataframe.head()

# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filteredn = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venuea.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filteredn['categories'] = dataframe_filteredn.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filteredn.columns = [column.split('.')[-1] for column in dataframe_filteredn.columns]
dataframe_filteredn
# Out:
#                               name                    categories  \
# 0             College Viva La Vida              Fraternity House
# 1            ALTRA College Centrum                        School
# 2   College Koninklijk Zeemanshoop                    Club House
# 3              College Frat Boys P              Fraternity House
# 4                 Marcanti College             Community College
# 5                College Frat Boys              Fraternity House
# 6              Frat Boys College R              Fraternity House
# 7              Frat Boys College Q              Fraternity House
# 8                          College                    University
# 9                     College-Club                        Office
# 10         Luzac College Amsterdam                        School
# 11                 Huygens College                   High School
# 12             Leidenhoven College     College Academic Building
# 13              Iedersland College  General College & University
# 14        Flight Attendant College                Student Center
# 15                Cannabis College          Marijuana Dispensary
# 16                   Media College         College Arts Building
# 17                   Luzac College                          None
# 18                   Altra College                   High School
# 19              Orion college West  General College & University
# 20               Collegezaal F0.01             College Classroom
# 21                 Ag bell college                   High School
# 22          Mediacollege Amsterdam  General College & University
#
#                             address       crossStreet        lat       lng  \
# 0                  Marnixstraat 229      Westerstraat  52.377743  4.878774
# 1                  Konijnenstraat 7       Hazenstraat  52.371140  4.881770
# 2                      Muntplein 10               NaN  52.366346  4.893132
# 3                  marnixstraat 221      westerstraat  52.376181  4.878048
# 4            Jan van Galenstraat 17               NaN  52.375232  4.865673
# 5                  marnixstraat 226      westerstraat  52.369146  4.876717
# 6                  marnixstraat 223      westerstraat  52.377719  4.878774
# 7                  marnixstraat 225      westerstraat  52.378679  4.878568
# 8                               NaN               NaN  52.385898  4.843427
# 9                   Oudebrugsteeg 9               NaN  52.373844  4.894876
# 10             Passeerdersgracht 25               NaN  52.366739  4.880632
# 11  2e constantijn huygensstraat 31               NaN  52.364408  4.872481
# 12            Roemer Visscherstraat               NaN  52.361042  4.875969
# 13                              NaN               NaN  52.370013  4.844079
# 14                              NaN               NaN  52.365182  4.892201
# 15      Oudezijds Achterburgwal 124               NaN  52.372140  4.897534
# 16                   condensatorweg               NaN  52.389748  4.851019
# 17                Prinsengracht 927               NaN  52.362220  4.891351
# 18               Stadhouderskade 60  Frans Halsstraat  52.358540  4.888616
# 19                   Zekeringstraat               NaN  52.395957  4.848846
# 20        Kloverniersburgwal (OMHP)               NaN  52.369303  4.896608
# 21                Zekeringstraat 45               NaN  52.395968  4.848865
# 22                    Contactweg 36               NaN  52.391117  4.856823
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 52.377743, 'lng':...       646    1015 WD
# 1   [{'label': 'display', 'lat': 52.3711399, 'lng'...       976    1016 SL
# 2   [{'label': 'display', 'lat': 52.36634615867874...      1914        NaN
# 3   [{'label': 'display', 'lat': 52.376181, 'lng':...       565     1015wd
# 4   [{'label': 'display', 'lat': 52.37523249608226...       286        NaN
# 5   [{'label': 'display', 'lat': 52.36914636209053...       891     1015wd
# 6   [{'label': 'display', 'lat': 52.37771864999999...       645     1015wd
# 7   [{'label': 'display', 'lat': 52.37867855409016...       673     1015wd
# 8   [{'label': 'display', 'lat': 52.385898, 'lng':...      2104        NaN
# 9   [{'label': 'display', 'lat': 52.37384380423829...      1724    1016 GX
# 10  [{'label': 'display', 'lat': 52.366739, 'lng':...      1262    1016 XG
# 11  [{'label': 'display', 'lat': 52.3644075066318,...      1296        NaN
# 12  [{'label': 'display', 'lat': 52.361042, 'lng':...      1710    1054 EW
# 13  [{'label': 'display', 'lat': 52.370013, 'lng':...      1864        NaN
# 14  [{'label': 'display', 'lat': 52.365182, 'lng':...      1939        NaN
# 15  [{'label': 'display', 'lat': 52.37213973022122...      1935    1012 DT
# 16  [{'label': 'display', 'lat': 52.38974757952646...      1995        NaN
# 17  [{'label': 'display', 'lat': 52.3622204511767,...      2118    1017 KD
# 18  [{'label': 'display', 'lat': 52.35854028997932...      2322    1072 AC
# 19  [{'label': 'display', 'lat': 52.39595746539847...      2642        NaN
# 20  [{'label': 'display', 'lat': 52.3693027607959,...      1969        NaN
# 21  [{'label': 'display', 'lat': 52.39596835311292...      2643        NaN
# 22  [{'label': 'display', 'lat': 52.39111693242768...      1904     1014AN
#
#     cc       city          state    country  \
# 0   NL  Amsterdam  Noord-Holland  Nederland
# 1   NL  Amsterdam  Noord-Holland  Nederland
# 2   NL  Amsterdam  Noord-Holland  Nederland
# 3   NL  Amsterdam  Noord-Holland  Nederland
# 4   NL  Amsterdam  Noord-Holland  Nederland
# 5   NL    Jordaan  Noord-Holland  Nederland
# 6   NL  Amsterdam  Noord-Holland  Nederland
# 7   NL    Jordaan  Noord-Holland  Nederland
# 8   NL        NaN            NaN  Nederland
# 9   NL  Amsterdam  Noord-Holland  Nederland
# 10  NL  Amsterdam  Noord-Holland  Nederland
# 11  NL  Amsterdam  Noord-Holland  Nederland
# 12  NL  Amsterdam  Noord-Holland  Nederland
# 13  NL        NaN            NaN  Nederland
# 14  NL        NaN            NaN  Nederland
# 15  NL  Amsterdam           1012  Nederland
# 16  NL  Amsterdam  Noord-Holland  Nederland
# 17  NL  Amsterdam  Noord-Holland  Nederland
# 18  NL  Amsterdam  Noord-Holland  Nederland
# 19  NL  Amsterdam  Noord-Holland  Nederland
# 20  NL  Amsterdam  Noord-Holland  Nederland
# 21  NL  Amsterdam  Noord-Holland  Nederland
# 22  NL  Amsterdam  Noord-Holland  Nederland
#
#                                      formattedAddress  \
# 0   [Marnixstraat 229 (Westerstraat), 1015 WD Amst...
# 1   [Konijnenstraat 7 (Hazenstraat), 1016 SL Amste...
# 2                [Muntplein 10, Amsterdam, Nederland]
# 3   [marnixstraat 221 (westerstraat), 1015wd Amste...
# 4      [Jan van Galenstraat 17, Amsterdam, Nederland]
# 5   [marnixstraat 226 (westerstraat), 1015wd Jorda...
# 6   [marnixstraat 223 (westerstraat), 1015wd Amste...
# 7   [marnixstraat 225 (westerstraat), 1015wd Jorda...
# 8                                         [Nederland]
# 9     [Oudebrugsteeg 9, 1016 GX Amsterdam, Nederland]
# 10  [Passeerdersgracht 25, 1016 XG Amsterdam, Nede...
# 11  [2e constantijn huygensstraat 31, Amsterdam, N...
# 12  [Roemer Visscherstraat, 1054 EW Amsterdam, Ned...
# 13                                        [Nederland]
# 14                                        [Nederland]
# 15  [Oudezijds Achterburgwal 124, 1012 DT Amsterda...
# 16             [condensatorweg, Amsterdam, Nederland]
# 17  [Prinsengracht 927, 1017 KD Amsterdam, Nederland]
# 18  [Stadhouderskade 60 (Frans Halsstraat), 1072 A...
# 19             [Zekeringstraat, Amsterdam, Nederland]
# 20  [Kloverniersburgwal (OMHP), Amsterdam, Nederland]
# 21          [Zekeringstraat 45, Amsterdam, Nederland]
# 22       [Contactweg 36, 1014AN Amsterdam, Nederland]
#
#                           id
# 0   4d0f2a16b765224b593be332
# 1   4d791e0371a68cfa16411186
# 2   5454b32f498ea36c77e07a52
# 3   4d0f3adbe236548177a570ea
# 4   4ad9b0aaf964a5206d1a21e3
# 5   4d0f2ac8d467236a4bafbc4a
# 6   4d0f2e65c3dc3704bcfd3074
# 7   4d0f2b306331a093d05e4f94
# 8   503db674e4b06abc4a39ee25
# 9   52460c932fc63e75960fac87
# 10  5dc29a3cc6ee7a00082d714e
# 11  4c0baa66009a0f47a25febbf
# 12  5acf3db632b61d325c0fa405
# 13  50ee712de4b01c4a89553c69
# 14  4d5925881d6cf04d330134fe
# 15  4c193bb59990d13acb327c17
# 16  4dcd05ecd22deadedd2de2bd
# 17  4b6a7cccf964a52098d62be3
# 18  4babc386f964a5207ac73ae3
# 19  4edc78cb722e1da304b6f176
# 20  4d468c6e0349224be9be0e4f
# 21  4e65bbe6aeb7360316510601
# 22  4b62c3f7f964a520c7512ae3

# %%
venues_map = folium.Map(location=[latitudea, longitudea], zoom_start=13) # generate map centred around the centroid of the Amsterdam cluster

# add a red circle marker to represent the Amsterdam centroid
folium.features.CircleMarker(
    [latitudea, longitudea],
    radius=10,
    color='red',
    popup='Amsterdam centroid',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Colleges & Universities as blue circle markers
for lat, lng, label in zip(dataframe_filteredn.lat, dataframe_filteredn.lng, dataframe_filteredn.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##  Analysis <a name="analysis"></a>

# %%
dataframe_filtered.drop(columns=['id', 'state', 'labeledLatLngs', 'postalCode', 'formattedAddress', 'address',
                                 'crossStreet', 'neighborhood', 'cc', 'lng', 'lat', 'city'])
# Out:
#                                                  name  \
# 0                         Kings College Student Union
# 1                Royal College of Surgeons of England
# 2                 Royal College Of Emergency Medicine
# 3             King's College London - Waterloo Campus
# 4               King's College London - Strand Campus
# 5           King's College - Language Resource Center
# 6                                  Kensington College
# 7                           University College London
# 8      LonDEC, King's College London Dental Institute
# 9                         University College Hospital
# 10                                       College Hall
# 11        King's College London - Drury Lane Building
# 12                                    Princes College
# 13                                 Goodenough College
# 14                                       Cats College
# 15                              Shakespearean College
# 16                              Global College London
# 17                          Eynsford Language College
# 18                    CCL (College of Central London)
# 19                          College Of Medicine - KSU
# 20                                    College Heights
# 21  MRC Laboartory for Molecular Cell Biology, Uni...
# 22                                    College of Arms
# 23                                   Williams College
# 24  King’s College London - Bush House North East ...
# 25                                    Gresham College
# 26                 London College Of Contemporary Art
# 27                    The College, 12 Southampton Row
# 28                Kaplan International College London
# 29                    London College of Communication
# 30                      College Of Emergency Medicine
# 31                 King's College London - Bush House
# 32                          King's College Law School
# 33         King's College London Sports & Social Club
# 34                     Library Royal College Surgeons
# 35  Centre For Telecommunications Research-king's ...
# 36                        st patricks college holborn
# 37                        cafe direct @ kings college
# 38                                     College of law
# 39       S2.31, King’s College London (Strand Campus)
#
#                                   categories  distance         country
# 0                             Student Center       726  United Kingdom
# 1                             Medical School       689  United Kingdom
# 2            College Administrative Building       373  United Kingdom
# 3                                 University      1090  United Kingdom
# 4                                 University       775  United Kingdom
# 5                      College Arts Building       753  United Kingdom
# 6            College Administrative Building       906  United Kingdom
# 7                                 University      2174  United Kingdom
# 8                             Medical School      1125  United Kingdom
# 9                                   Hospital      2373  United Kingdom
# 10                    College Residence Hall      1912  United Kingdom
# 11                                University      1164  United Kingdom
# 12                                    Office      1349  United Kingdom
# 13                            Student Center      1540  United Kingdom
# 14                 College Academic Building      1152  United Kingdom
# 15              General College & University      1542  United Kingdom
# 16                 College Academic Building        93  United Kingdom
# 17              General College & University      1771  United Kingdom
# 18              General College & University      1948  United Kingdom
# 19                            Medical School       461  United Kingdom
# 20  Residential Building (Apartment / Condo)      1272  United Kingdom
# 21                               Medical Lab      2060  United Kingdom
# 22                       Monument / Landmark       621  United Kingdom
# 23                 College Academic Building       285  United Kingdom
# 24                 College Academic Building       754  United Kingdom
# 25                                University       409  United Kingdom
# 26              General College & University       475  United Kingdom
# 27                 College Academic Building      1124  United Kingdom
# 28              General College & University      2009  United Kingdom
# 29                     College Arts Building      2236  United Kingdom
# 30                            Medical School      1033  United Kingdom
# 31               College Technology Building       770  United Kingdom
# 32                                Law School       838  United Kingdom
# 33                               Social Club       730  United Kingdom
# 34                           College Library       675  United Kingdom
# 35                 College Academic Building       731  United Kingdom
# 36                 College Academic Building       598  United Kingdom
# 37                                      Café       764  United Kingdom
# 38                                Law School      1394  United Kingdom
# 39                         College Classroom       752  United Kingdom

# %%
dataframe_filteredc.drop(columns=['id', 'state', 'labeledLatLngs', 'postalCode', 'formattedAddress', 'address', 
                                  'cc', 'lng', 'lat', 'city'])
# Out:
#                                        name                    categories  \
# 0  Cambridge Regional College Sports Centre          Gym / Fitness Center
# 1          LRC @ Cambridge Regional College               College Library
# 2          Cambridge Regional College (CRC)                  Trade School
# 3                       College fields park                          Park
# 4          Bellerbys College Campus Library                       Library
# 5              Chesterton Community College             Community College
# 6                 Impington Village College  General College & University
# 7                Christ's College Boathouse          Gym / Fitness Center
#
#    distance         country
# 0       171  United Kingdom
# 1       204  United Kingdom
# 2       236  United Kingdom
# 3      1103  United Kingdom
# 4      1221  United Kingdom
# 5      2268  United Kingdom
# 6      1932  United Kingdom
# 7      2587  United Kingdom

# %%
dataframe_filteredn.drop(columns=['id', 'state', 'labeledLatLngs', 'postalCode', 'formattedAddress', 'address',
                                 'crossStreet', 'cc', 'lng', 'lat', 'city'])
# Out:
#                               name                    categories  distance  \
# 0             College Viva La Vida              Fraternity House       646
# 1            ALTRA College Centrum                        School       976
# 2   College Koninklijk Zeemanshoop                    Club House      1914
# 3              College Frat Boys P              Fraternity House       565
# 4                 Marcanti College             Community College       286
# 5                College Frat Boys              Fraternity House       891
# 6              Frat Boys College R              Fraternity House       645
# 7              Frat Boys College Q              Fraternity House       673
# 8                          College                    University      2104
# 9                     College-Club                        Office      1724
# 10         Luzac College Amsterdam                        School      1262
# 11                 Huygens College                   High School      1296
# 12             Leidenhoven College     College Academic Building      1710
# 13              Iedersland College  General College & University      1864
# 14        Flight Attendant College                Student Center      1939
# 15                Cannabis College          Marijuana Dispensary      1935
# 16                   Media College         College Arts Building      1995
# 17                   Luzac College                          None      2118
# 18                   Altra College                   High School      2322
# 19              Orion college West  General College & University      2642
# 20               Collegezaal F0.01             College Classroom      1969
# 21                 Ag bell college                   High School      2643
# 22          Mediacollege Amsterdam  General College & University      1904
#
#       country
# 0   Nederland
# 1   Nederland
# 2   Nederland
# 3   Nederland
# 4   Nederland
# 5   Nederland
# 6   Nederland
# 7   Nederland
# 8   Nederland
# 9   Nederland
# 10  Nederland
# 11  Nederland
# 12  Nederland
# 13  Nederland
# 14  Nederland
# 15  Nederland
# 16  Nederland
# 17  Nederland
# 18  Nederland
# 19  Nederland
# 20  Nederland
# 21  Nederland
# 22  Nederland

# %% [markdown]
# As we can see trough the multiple maps and now this dataframes, the number of college and univirsities ara significatively high per number of companies on the list, being aware that we have a radius of 2km. Not many places in Europe have around 40 or more venues related with those parameters within 2km. Visualize the data in this case is difficult due to the fact that the size of the DataFrames are different and even being easy to do so, we do not count with many more information as restaurant and others due to the limited number of calls that we can do with Foursquare API.

# %% [markdown]
# ## Results <a name="results"></a>

# %% [markdown]
# After all the process done, we can determine visually a clear correlation between the location and the suceess of that companies. Trough the agglomerative clusters of GB, we can appreciate clearly the distribution and the nucleus of these.
# In Scotland the cluster is defined with Glasgow and Edinbourgh, in London is cristal clear the agglomeration, separatedly but with a similar distribution we have two clusters more, in Cambridge and Oxford respectively and then we have two clusters with a interesting composition. We can see with less agglomeration, the nucleus in Manchester but having companies in Liverpool too and last but not least we see a distribution following almost vertically the cities of Leeds, Sheffield, Nottingham, Derby and Birmingham. In the last cluster it would be really interesting check the communication facilites in the arounds because it seems to follow another sort of pattern than the other clusters with a relative proximity in the same cluster but clearly communicated by a central highway.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# In a exercice of self criticism I would say that I tried to extract conclusions of a subject that is for more experimented programers and data scientists, as I spend barely two month by now learning Python. The remarkable interest of this subject is anyway worth trying because many times we see a extremely close scope on our disciplines and we totally lose the perspective of the problems to solve. In this case, we can try hundreds of ways to determine why a company is succesful, checking their market cap, revenues and as much financial terms as you want, but seeing a relation in what we would not spend time thinking about as the location of this companies is sometimes awakening. It has been spending time researching for and interesting topic that I have discovered what it is the Economy of agglomerations and the benefits of this discipline.
