# %% [markdown]
# # Economy of agglomeration on Business Clusters

# %% [markdown]
# ## Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction and Purpose](#introduction)
# * [Methodology](#methodology)
# * [Data](#data)
# * [Analysis](#analysis)
# * [Results](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction and Purpose <a name="introduction"></a>

# %% [markdown]
# All-round the world companies and small businesses are agglomerated in one district or around. This agglomeration contributes significatively to decreasing the price of production, deployment, as it does on creating a more innovative and productive environment for their employees. Many of these effects are widely known on business clusters and lately have shown amazing results on other sectors such as biotech, high-tech, and so on, having a great example on BioPharma clusters in Switzerland or HighTech ecosystems in other countries.
#
# The success of a company is not determined by the location of the office although it can affect directly, as clusters pretend to do. Knowing that this project is a beginner-intermediate one and the subject chosen is complex if it is studied in complete detail, the results will be shown as probable, without determining the rest of the factors that can affect the success in the location of your company or your services around a particular location. As the capstone project demands it will be using Foursquare API that we will get the data to find relations.
#
# The purpose of this project is to give possible solutions, in the location of the company, for these expecting to grow fast in a short time, in the same way, contribute to the proper location of services and franchises when you want them located in these clusters.
#
# I encourage anyone with knowledge and interest in this field to use my work and find out more about the relationship between business, biopharma, or startup clusters and their location and services around the same. I think that these models can be of remarkable interest for all the countries that are developing their clusters to do it successfully, particularly now, that we live a pharmaceutical revolution due to the current situation with Covid-19.
#
# TO SEE PROPERLY THE MAPS INTRODUCE THE NOTEBOOK IN https://nbviewer.org/

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# The stages from acquisition to deploy a solution have been the next:
#
# - Acquisition of Data trough Deloitte's PDF EMEA Fast Growth 2019 and the consequent cleaning.
# - Location of the address, latitude and longitude of the companies listes using GeoCode API of Google.
# - Mapping using floium the companies by the industry sector and cluster them with k-means.
# - Identify services around companies by sector using Foursquare API.
# - Analysing and visualizing the results.

# %%
import numpy as np
import sys
import geopy
import seaborn as sns
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import csv
import pylab as pl
import urllib.parse
import folium
import json
import geojson
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
from folium.folium import Map
from sklearn.cluster import AgglomerativeClustering
from geopy.geocoders import Nominatim, GoogleV3      # convert an address into latitude and longitude values
from pandas.io.json import json_normalize            # tranform JSON file into a pandas dataframe
from sklearn.cluster import KMeans

# %matplotlib inline

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# ### Acquisition of Data

# %%
df = pd.read_csv("C:/Users/marc/Desktop/Notebook/gx-emea_fast_500_Ranking-2019.csv")
df.dropna(how='any', inplace = True)
df.drop(df.index[[25, 51, 77, 103, 129, 155, 181, 206, 230, 256, 282, 308, 334, 359, 384, 409, 435, 461, 486]], inplace = True)
df['Growth'] = df['Growth'].apply(lambda x: int(x.split("%")[0].replace(' ', '')))
df.rename(columns={'Growth': 'Growth %', 'Company name for communication': 'Company', 'Industry sector': 'Sector'})
df1 = df  #Saving the original DataFrame for other uses
df
# At this stage the dataframe has been cleaned of NaN's and other unuseful values
# Out:
#     Ranking Company name for communication    Country  Growth  \
# 0         1                        Revolut         UK   39754
# 1         2                       OakNorth         UK   30706
# 2         3   Cloud&Heat Technologies GmbH         DE   21474
# 3         4                      DivideBuy         UK   19572
# 4         5                        FINEWAY         DE   16594
# ..      ...                            ...        ...     ...
# 571     496                    shopware AG         DE     159
# 572     497            metacrew group GmbH         DE     159
# 573     498                         LESCAV    Belgium     158
# 574     499                     Paysera LT  Lithuania     158
# 575     500                   Arcus Global         UK     157
#
#               Industry sector
# 0                     Fintech
# 1                     Fintech
# 2    Environmental Technology
# 3                     Fintech
# 4                    Software
# ..                        ...
# 571                  Software
# 572   Media and Entertainment
# 573                  Hardware
# 574                   Fintech
# 575                  Software
#
# [493 rows x 5 columns]

# %% [markdown]
# ### UK DataFrame

# %%
#Code to inspect the data by sector and countries
df['Industry sector'].value_counts()
df['Country'].value_counts()

# I will choose UK as it is de country with more companies for the first analysis
df = df[df['Country'] == 'UK'] 
# I will work with these companies which are more than five in the same sector
df = df[df['Industry sector'] != 'Environmental Technology'] 
df = df[df['Industry sector'] != 'Communications']
df = df[df['Industry sector'] != 'Healthcare and Life Sciences']

df.head(15)
# Out:
#    Ranking Company name for communication Country  Growth  \
# 0        1                        Revolut      UK   39754
# 1        2                       OakNorth      UK   30706
# 3        4                      DivideBuy      UK   19572
# 11      12                        Moteefe      UK    7394
# 20      21                    Clearmatics      UK    4900
# 29      26                     ClearScore      UK    4382
# 33      30                       Lendable      UK    3883
# 43      40                       Privitar      UK    2797
# 49      46                         Onfido      UK    2324
# 63      56                         Paddle      UK    2013
# 65      58                      Darktrace      UK    1989
# 66      59                     Streetbees      UK    1984
# 72      65  Iceotope Technologies Limited      UK    1895
# 93      82                           Yoyo      UK    1707
# 95      84                      Hostmaker      UK    1592
#
#             Industry sector
# 0                   Fintech
# 1                   Fintech
# 3                   Fintech
# 11  Media and Entertainment
# 20                 Software
# 29                  Fintech
# 33                  Fintech
# 43                 Software
# 49                  Fintech
# 63                 Software
# 65                 Software
# 66                 Software
# 72                 Hardware
# 93                  Fintech
# 95                 Software

# %% [markdown]
# ### Netherlands DataFrame

# %%
# Using the original DataFrame we see NL as the second country with more companies on the list
df1['Country'].value_counts()
df1 = df1[df1['Country'] == 'NL']
# We will work with companyes with at least five times on the sector in the NL
df1['Industry sector'].value_counts()
df1 = df1[df1['Industry sector'] != 'Communications']
df1 = df1[df1['Industry sector'] != 'Healthcare and Life Sciences']
df1 = df1[df1['Industry sector'] != 'Fintech']
df1 = df1[df1['Industry sector'] != 'Hardware']
df1.head(20)
# Out:
#     Ranking Company name for communication Country  Growth  \
# 9        10         Flightgift / Hotelgift      NL    7628
# 16       17                   Mews Systems      NL    5384
# 21       22                       PastBook      NL    4623
# 39       36                     Simplicate      NL    3013
# 81       74                      Channable      NL    1791
# 104      93                Scrambled Group      NL    1458
# 117     102                        Appwiki      NL    1281
# 122     107                        3D Hubs      NL    1258
# 126     111                         Parkos      NL    1234
# 134     119                         POSTEX      NL    1164
# 135     120                   Team Nijhuis      NL    1156
# 139     124                  APOC Aviation      NL    1088
# 155     136               The Inner Circle      NL     963
# 178     155                     Zelfstroom      NL     895
# 187     164                      SendCloud      NL     856
# 211     184                        Cloud++      NL     769
# 213     186                      Studytube      NL     755
# 253     222              Stars and Stories      NL     654
# 270     235                          Mapiq      NL     597
# 272     237                     SecureLink      NL     588
#
#               Industry sector
# 9                    Software
# 16                   Software
# 21    Media and Entertainment
# 39                   Software
# 81                   Software
# 104   Media and Entertainment
# 117   Media and Entertainment
# 122                  Software
# 126                  Software
# 134                  Software
# 135   Media and Entertainment
# 139                  Software
# 155   Media and Entertainment
# 178  Environmental Technology
# 187  Environmental Technology
# 211                  Software
# 213                  Software
# 253   Media and Entertainment
# 270                  Software
# 272                  Software

# %% [markdown]
# ### Geolocation of UK Companies

# %%
#Set instructions to use Google API
base_url= "https://maps.googleapis.com/maps/api/geocode/json?"
AUTH_KEY = "AIzaSyAkvUUxfKc4Z5uMv58wOsd2usIdDHvxQTk"
geolocator = GoogleV3(api_key = AUTH_KEY)

components = [ ('country', 'GB' )]
def get_location(x):
    return geolocator.geocode(x, components=components)

df["loc"] = df["Company name for communication"].apply(get_location)
df["point"]= df["loc"].apply(lambda loc: tuple(loc.point) if loc else None)
df[['lat', 'lon', 'altitude']] = pd.DataFrame(df['point'].to_list(), index=df.index)
## Adding manually the information that has not been reached by the API
df.loc[43,'loc'] = '(15 Hatfields, South Bank, London SE1 8DJ, United Kingdom)'
df.loc[43,'point'] = '(51.506855, -0.107148)'
df.loc[43,'lat'] = 51.50685
df.loc[43,'lon'] = -0.10714
df.loc[43,'altitude'] = '0'
df.loc[72,'loc'] = '(Brunel Way, Catcliffe, Rotherham S60 5WG, United Kingdom)'
df.loc[72,'point'] = '(53.386183, -1.378254)'
df.loc[72,'lat'] = 53.38618
df.loc[72,'lon'] = -1.378254
df.loc[72,'altitude'] = '0'
df.loc[121,'loc'] = '(175 Glasgow Rd, Edinburgh EH12 9SB, United Kingdom)'
df.loc[121,'point'] = '(55.934881, -3.334630)'
df.loc[121,'lat'] = 55.93488
df.loc[121,'lon'] = -3.33463
df.loc[121,'altitude'] = '0'
df.loc[214,'loc'] = '(49 Jamaica St, Liverpool L1 0AH, United Kingdom)'
df.loc[214,'point'] = '(53.395409, -2.980149)'
df.loc[214,'lat'] = 53.3954
df.loc[214,'lon'] = -2.98014
df.loc[214,'altitude'] = '0'
df.loc[326,'loc'] = '(1st Floor, 99 Clifton Street, London EC2A 4LG)'
df.loc[326,'point'] = '(51.522996, -0.083417)'
df.loc[326,'lat'] = 51.52299
df.loc[326,'lon'] = -0.08341
df.loc[326,'altitude'] = '0'
df.loc[395,'loc'] = '(25 Greenside Pl, Edinburgh EH1 3AA, United Kingdom)'
df.loc[395,'point'] = '(55.957294, -3.185021)'
df.loc[395,'lat'] = 55.95729
df.loc[395,'lon'] = -3.18502
df.loc[395,'altitude'] = '0'
df.loc[435,'loc'] = '(5th Floor, House, 52, 54 High Holborn, Holborn, London WC1V 6RL, United Kingdom)'
df.loc[435,'point'] = '(51.518419, -0.115012)'
df.loc[435,'lat'] = 51.51841
df.loc[435,'lon'] = -0.11501
df.loc[435,'altitude'] = '0'
df.loc[450,'loc'] = '(Screenworks Building, London N5 2EF, United Kingdom)'
df.loc[450,'point'] = '(51.550740, -0.097063)'
df.loc[450,'lat'] = 51.55074
df.loc[450,'lon'] = -0.09706
df.loc[450,'altitude'] = '0'
df.loc[480,'loc'] = '(5 Langley St, Covent Garden, London WC2H 9JA, United Kingdom)'
df.loc[480,'point'] = '(51.513187, -0.124933)'
df.loc[480,'lat'] = 51.51318
df.loc[480,'lon'] = -0.12493
df.loc[480,'altitude'] = '0'
df.loc[530,'loc'] = '(25 Wilton Road, Victoria, London, UK)'
df.loc[530,'point'] = '(51.495242, -0.142358)'
df.loc[530,'lat'] = 51.49524
df.loc[530,'lon'] = -0.14235
df.loc[530,'altitude'] = '0'

# %%
df.drop(columns=['altitude'])
# Out:
#     Ranking Company name for communication Country  Growth  \
# 0         1                        Revolut      UK   39754
# 1         2                       OakNorth      UK   30706
# 3         4                      DivideBuy      UK   19572
# 11       12                        Moteefe      UK    7394
# 20       21                    Clearmatics      UK    4900
# ..      ...                            ...     ...     ...
# 541     470                     Cloudhouse      UK     183
# 543     472                          Zappi      UK     180
# 565     490                       disguise      UK     162
# 568     493                    Purple WiFi      UK     161
# 575     500                   Arcus Global      UK     157
#
#              Industry sector  \
# 0                    Fintech
# 1                    Fintech
# 3                    Fintech
# 11   Media and Entertainment
# 20                  Software
# ..                       ...
# 541                 Software
# 543                 Software
# 565                 Software
# 568                 Software
# 575                 Software
#
#                                                    loc  \
# 0             (United Kingdom, (55.378051, -3.435973))
# 1    (57 Broadwick St, Carnaby, London W1F 9QS, UK,...
# 3    (First Floor, Brunswick Court, Brunswick St, N...
# 11   (84 Eccleston Square, Pimlico, London SW1V 1NP...
# 20   (30 City Rd, London EC1Y 2AY, UK, (51.5226132,...
# ..                                                 ...
# 541  (1 Ariel Way, London W12 7SL, UK, (51.5091304,...
# 543  (The Enterprise Village, Prince Albert Gardens...
# 565           (United Kingdom, (55.378051, -3.435973))
# 568           (United Kingdom, (55.378051, -3.435973))
# 575  (Future Business Centre, Kings Hedges Rd, Camb...
#
#                                        point        lat       lon
# 0                (55.378051, -3.435973, 0.0)  55.378051 -3.435973
# 1              (51.5130211, -0.1373418, 0.0)  51.513021 -0.137342
# 3               (53.0123213, -2.220778, 0.0)  53.012321 -2.220778
# 11             (51.4931108, -0.1435609, 0.0)  51.493111 -0.143561
# 20   (51.5226132, -0.08738939999999999, 0.0)  51.522613 -0.087389
# ..                                       ...        ...       ...
# 541            (51.5091304, -0.2231225, 0.0)  51.509130 -0.223123
# 543            (53.5731559, -0.0772785, 0.0)  53.573156 -0.077278
# 565              (55.378051, -3.435973, 0.0)  55.378051 -3.435973
# 568              (55.378051, -3.435973, 0.0)  55.378051 -3.435973
# 575               (52.234851, 0.129525, 0.0)  52.234851  0.129525
#
# [91 rows x 9 columns]

# %%
df.point.isna().sum()
df.dropna(subset=['point'], inplace=True)

# %% [markdown]
# ### Geolocation of Netherlands Companies

# %%
#Set instructions to use Google API
base_url= "https://maps.googleapis.com/maps/api/geocode/json?"
AUTH_KEY = "AIzaSyAkvUUxfKc4Z5uMv58wOsd2usIdDHvxQTk"
geolocator = GoogleV3(api_key = AUTH_KEY)

components = [ ('country', 'NL' )]
def get_location(x):
    return geolocator.geocode(x, components=components)

df1["loc"] = df1["Company name for communication"].apply(get_location)
df1["point"]= df1["loc"].apply(lambda loc: tuple(loc.point) if loc else None)
df1[['lat', 'lon', 'altitude']] = pd.DataFrame(df1['point'].to_list(), index=df1.index)
df1.loc[211,'loc'] = '(Kruisstraat 5, 8501 BP Joure, Netherlands)'
df1.loc[211,'point'] = '(52.969678, 5.793303)'
df1.loc[211,'lat'] = 52.969678
df1.loc[211,'lon'] = 5.793303
df1.drop(columns=['altitude'])
# Out:
#     Ranking Company name for communication Country  Growth  \
# 9        10         Flightgift / Hotelgift      NL    7628
# 16       17                   Mews Systems      NL    5384
# 21       22                       PastBook      NL    4623
# 39       36                     Simplicate      NL    3013
# 81       74                      Channable      NL    1791
# ..      ...                            ...     ...     ...
# 532     461                       FiscFree      NL     189
# 538     467                      FindHotel      NL     185
# 544     473                    SpriteCloud      NL     177
# 560     485      Intus Workforce Solutions      NL     167
# 567     492                 Pimm Solutions      NL     162
#
#              Industry sector  \
# 9                   Software
# 16                  Software
# 21   Media and Entertainment
# 39                  Software
# 81                  Software
# ..                       ...
# 532                 Software
# 538                 Software
# 544                 Software
# 560                 Software
# 567                 Software
#
#                                                    loc  \
# 9    (Herengracht 493, 1017 BT Amsterdam, Netherlan...
# 16   (Wibautstraat 137D, 1097 DN Amsterdam, Netherl...
# 21   (A'dam Tower, Overhoeksplein 3, 1031 KS Amster...
# 39   (Laan Corpus Den Hoorn 102-1, 9728 JR Groninge...
# 81   (Kromme Nieuwegracht 66, 3512 HL Utrecht, Neth...
# ..                                                 ...
# 532  (Industrieweg 8, 8444 AS Heerenveen, Netherlan...
# 538  (Nieuwe Looiersdwarsstraat 17, 1017 TZ Amsterd...
# 544  (Generaal Vetterstraat 72b, 1059 BW Amsterdam,...
# 560  (Princenhof Park 12, 3972 NG Driebergen-Rijsen...
# 567  (Westblaak 180, 3012 KN Rotterdam, Netherlands...
#
#                                     point        lat       lon
# 9             (52.365714, 4.8910971, 0.0)  52.365714  4.891097
# 16   (52.3495268, 4.917836599999999, 0.0)  52.349527  4.917837
# 21            (52.3839102, 4.902474, 0.0)  52.383910  4.902474
# 39           (53.1937232, 6.5536279, 0.0)  53.193723  6.553628
# 81   (52.0906417, 5.125939700000001, 0.0)  52.090642  5.125940
# ..                                    ...        ...       ...
# 532          (52.9329834, 5.9481348, 0.0)  52.932983  5.948135
# 538            (52.360783, 4.893751, 0.0)  52.360783  4.893751
# 544            (52.343881, 4.846614, 0.0)  52.343881  4.846614
# 560          (52.0658397, 5.2583797, 0.0)  52.065840  5.258380
# 567           (51.9163212, 4.475754, 0.0)  51.916321  4.475754
#
# [64 rows x 9 columns]

# %%
df1.point.isna().sum()
df1.dropna(subset=['point'], inplace=True)

# %% [markdown]
# ### Mapping Netherlands Companies by sector

# %%
## Now that we can see the map we can delete the outlier companies 
df1 = df1[df1['Company name for communication'] != 'Grizzly New Marketing']
df1 = df1[df1['Company name for communication'] != 'Cloud++']
df1 = df1[df1['Company name for communication'] != 'FiscFree']
df1 = df1[df1['Company name for communication'] != 'Stars and Stories']
x = list(zip(df1['lon'].values, df1['lat'].values))
## We can use the agglomerativeclustering to locate the claster easily
clustering = AgglomerativeClustering(7).fit(x)
clustering.labels_
df1['cluster'] = clustering.labels_
df1
# Out:
#     Ranking Company name for communication Country  Growth  \
# 9        10         Flightgift / Hotelgift      NL    7628
# 16       17                   Mews Systems      NL    5384
# 21       22                       PastBook      NL    4623
# 39       36                     Simplicate      NL    3013
# 81       74                      Channable      NL    1791
# 104      93                Scrambled Group      NL    1458
# 117     102                        Appwiki      NL    1281
# 122     107                        3D Hubs      NL    1258
# 126     111                         Parkos      NL    1234
# 134     119                         POSTEX      NL    1164
# 135     120                   Team Nijhuis      NL    1156
# 139     124                  APOC Aviation      NL    1088
# 155     136               The Inner Circle      NL     963
# 178     155                     Zelfstroom      NL     895
# 187     164                      SendCloud      NL     856
# 213     186                      Studytube      NL     755
# 270     235                          Mapiq      NL     597
# 272     237                     SecureLink      NL     588
# 273     238                         Foleon      NL     581
# 274     239                        JouwWeb      NL     578
# 280     245                        Speakap      NL     554
# 283     248                2Solar software      NL     549
# 294     255                        Scribbr      NL     532
# 305     266                    MessageBird      NL     504
# 308     269            Robin Radar Systems      NL     493
# 327     284                        Rentman      NL     459
# 334     291                        OBI4wan      NL     442
# 348     301                    The Next Ad      NL     422
# 351     304                    Yellowgrape      NL     415
# 352     305                        Roamler      NL     411
# 353     306                        VanMoof      NL     411
# 356     309                 Annual Insight      NL     408
# 364     317                Building Blocks      NL     391
# 366     319                    ROBINHQ.COM      NL     386
# 370     323                       Concapps      NL     374
# 371     324                           Plek      NL     374
# 372     325                 CustomConcepts      NL     364
# 377     326                        Relay42      NL     364
# 386     335                HousingAnywhere      NL     346
# 387     336                      Firmhouse      NL     346
# 391     340                           Jalt      NL     339
# 397     346                       ViriCiti      NL     330
# 409     354                       MediMapp      NL     320
# 414     359           New York Media Group      NL     314
# 415     360               Werk aan de Muur      NL     312
# 420     365                         Gadero      NL     309
# 425     370                    Mail to Pay      NL     298
# 426     371                      24i Media      NL     298
# 456     397                     Helloprint      NL     259
# 472     409                  Meetingselect      NL     245
# 479     416                     EDC Retail      NL     229
# 481     418                         Ecotap      NL     228
# 505     438                      ValidSign      NL     212
# 509     442                  I-team Global      NL     205
# 510     443                    JAMwerkt.nl      NL     203
# 528     457                   Creative ICT      NL     192
# 538     467                      FindHotel      NL     185
# 544     473                    SpriteCloud      NL     177
# 560     485      Intus Workforce Solutions      NL     167
# 567     492                 Pimm Solutions      NL     162
#
#               Industry sector  \
# 9                    Software
# 16                   Software
# 21    Media and Entertainment
# 39                   Software
# 81                   Software
# 104   Media and Entertainment
# 117   Media and Entertainment
# 122                  Software
# 126                  Software
# 134                  Software
# 135   Media and Entertainment
# 139                  Software
# 155   Media and Entertainment
# 178  Environmental Technology
# 187  Environmental Technology
# 213                  Software
# 270                  Software
# 272                  Software
# 273                  Software
# 274                  Software
# 280                  Software
# 283                  Software
# 294                  Software
# 305                  Software
# 308                  Software
# 327                  Software
# 334                  Software
# 348   Media and Entertainment
# 351   Media and Entertainment
# 352                  Software
# 353                  Software
# 356                  Software
# 364                  Software
# 366                  Software
# 370                  Software
# 371                  Software
# 372   Media and Entertainment
# 377                  Software
# 386                  Software
# 387                  Software
# 391   Media and Entertainment
# 397  Environmental Technology
# 409                  Software
# 414   Media and Entertainment
# 415                  Software
# 420                  Software
# 425                  Software
# 426   Media and Entertainment
# 456                  Software
# 472                  Software
# 479   Media and Entertainment
# 481  Environmental Technology
# 505                  Software
# 509  Environmental Technology
# 510                  Software
# 528   Media and Entertainment
# 538                  Software
# 544                  Software
# 560                  Software
# 567                  Software
#
#                                                    loc  \
# 9    (Herengracht 493, 1017 BT Amsterdam, Netherlan...
# 16   (Wibautstraat 137D, 1097 DN Amsterdam, Netherl...
# 21   (A'dam Tower, Overhoeksplein 3, 1031 KS Amster...
# 39   (Laan Corpus Den Hoorn 102-1, 9728 JR Groninge...
# 81   (Kromme Nieuwegracht 66, 3512 HL Utrecht, Neth...
# 104      (Netherlands, (52.132633, 5.291265999999999))
# 117  (Heresingel 4, B, 9711 ES Groningen, Netherlan...
# 122      (Netherlands, (52.132633, 5.291265999999999))
# 126      (Netherlands, (52.132633, 5.291265999999999))
# 134      (Netherlands, (52.132633, 5.291265999999999))
# 135  (Prins Bernhardlaan 59, 7622 BE Borne, Netherl...
# 139  (Industrieweg 48, 2651 BE Berkel en Rodenrijs,...
# 155      (Netherlands, (52.132633, 5.291265999999999))
# 178  (Statenlaan 14, 5223 LA 's-Hertogenbosch, Neth...
# 187  (Stadhuisplein 10, 5611 EM Eindhoven, Netherla...
# 213  (Naritaweg 70, 1043 BZ Amsterdam, Netherlands,...
# 270  (Oostsingel 209, 2612 HL Delft, Netherlands, (...
# 272      (Netherlands, (52.132633, 5.291265999999999))
# 273  (4th floor, Transformatorweg 38-72, 1014 AK Am...
# 274      (Netherlands, (52.132633, 5.291265999999999))
# 280  (Pedro de Medinalaan 5, 1086 XK Amsterdam, Net...
# 283  (Zuiderzeelaan 17A, 8017 JV Zwolle, Netherland...
# 294  (Singel 542, 1017 AZ Amsterdam, Netherlands, (...
# 305  (Trompenburgstraat 2C, 1079 TX Amsterdam, Neth...
# 308  (Laan van Waalhaven 355, 2497 GM Den Haag, Net...
# 327  (Drift 17, 3512 BR Utrecht, Netherlands, (52.0...
# 334  (Korte Hogendijk 2, 1506 MA Zaandam, Netherlan...
# 348  (Transformatorweg 88, 1014 AK Amsterdam, Nethe...
# 351  (Herengracht 231, 1016 BG Amsterdam, Netherlan...
# 352  (NDSM-Plein 20, 1033 WC Amsterdam, Netherlands...
# 353  (Mauritskade 55, 1092 AD Amsterdam, Netherland...
# 356      (Netherlands, (52.132633, 5.291265999999999))
# 364      (Netherlands, (52.132633, 5.291265999999999))
# 366      (Netherlands, (52.132633, 5.291265999999999))
# 370  (Veemarktkade 8, 5222 AE 's-Hertogenbosch, Net...
# 371      (Netherlands, (52.132633, 5.291265999999999))
# 372  (Gillis van Ledenberchstraat 74, 1052 VK Amste...
# 377  (Meeuwenlaan 100, 1021 JL Amsterdam, Netherlan...
# 386      (Netherlands, (52.132633, 5.291265999999999))
# 387  (Stationsplein 45, 3013 AK Rotterdam, Netherla...
# 391      (Netherlands, (52.132633, 5.291265999999999))
# 397  (Kabelweg 57, 1014 BA Amsterdam, Netherlands, ...
# 409      (Netherlands, (52.132633, 5.291265999999999))
# 414      (Netherlands, (52.132633, 5.291265999999999))
# 415  (Hendrik Figeeweg 3G, 6, 2031 BJ Haarlem, Neth...
# 420  (Straatweg 5, 3621 BG Breukelen, Netherlands, ...
# 425  (Van Coulsterweg 2, 2952 CB Alblasserdam, Neth...
# 426  (Transformatorweg 78, 1014 AK Amsterdam, Nethe...
# 456  (Schiedamse Vest 89, 3012 BG Rotterdam, Nether...
# 472  (De Witte Toren, Rijksweg 81 a, 1411 GE Naarde...
# 479  (Phoenixweg 6, 9641 KS Veendam, Netherlands, (...
# 481      (Netherlands, (52.132633, 5.291265999999999))
# 505  (Zutphenseweg 42, 7211 ED Eefde, Netherlands, ...
# 509  (Hoppenkuil 27B, 5626 DD Eindhoven, Netherland...
# 510  (Freddy van Riemsdijkweg 28, 5657 EE Eindhoven...
# 528  (M. H. Tromplaan 3, 7511 JJ Enschede, Netherla...
# 538  (Nieuwe Looiersdwarsstraat 17, 1017 TZ Amsterd...
# 544  (Generaal Vetterstraat 72b, 1059 BW Amsterdam,...
# 560  (Princenhof Park 12, 3972 NG Driebergen-Rijsen...
# 567  (Westblaak 180, 3012 KN Rotterdam, Netherlands...
#
#                                            point        lat       lon  \
# 9                    (52.365714, 4.8910971, 0.0)  52.365714  4.891097
# 16          (52.3495268, 4.917836599999999, 0.0)  52.349527  4.917837
# 21                   (52.3839102, 4.902474, 0.0)  52.383910  4.902474
# 39                  (53.1937232, 6.5536279, 0.0)  53.193723  6.553628
# 81          (52.0906417, 5.125939700000001, 0.0)  52.090642  5.125940
# 104          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 117                 (53.2138115, 6.5704626, 0.0)  53.213811  6.570463
# 122          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 126          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 134          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 135           (52.30901, 6.741034000000001, 0.0)  52.309010  6.741034
# 139                 (51.9829849, 4.4566059, 0.0)  51.982985  4.456606
# 155          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 178          (51.68984589999999, 5.2902558, 0.0)  51.689846  5.290256
# 187         (51.4350475, 5.479492899999999, 0.0)  51.435048  5.479493
# 213         (52.3881878, 4.825226100000001, 0.0)  52.388188  4.825226
# 270                  (52.0200648, 4.351446, 0.0)  52.020065  4.351446
# 272          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 273         (52.3923186, 4.848865000000001, 0.0)  52.392319  4.848865
# 274          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 280                 (52.3633593, 4.9783301, 0.0)  52.363359  4.978330
# 283                 (52.5026079, 6.0825808, 0.0)  52.502608  6.082581
# 294                 (52.3666451, 4.8923966, 0.0)  52.366645  4.892397
# 305                 (52.3442332, 4.9116167, 0.0)  52.344233  4.911617
# 308                 (52.0415423, 4.3610118, 0.0)  52.041542  4.361012
# 327                 (52.0937913, 5.1233833, 0.0)  52.093791  5.123383
# 334                   (52.436906, 4.815436, 0.0)  52.436906  4.815436
# 348                 (52.3926183, 4.8479576, 0.0)  52.392618  4.847958
# 351                 (52.3727001, 4.8874685, 0.0)  52.372700  4.887468
# 352         (52.4005369, 4.893499600000001, 0.0)  52.400537  4.893500
# 353                 (52.3617287, 4.9177479, 0.0)  52.361729  4.917748
# 356          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 364          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 366          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 370                 (51.7016028, 5.2862063, 0.0)  51.701603  5.286206
# 371          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 372         (52.3763143, 4.871489299999999, 0.0)  52.376314  4.871489
# 377                 (52.3856953, 4.9216761, 0.0)  52.385695  4.921676
# 386          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 387                 (51.9232492, 4.4692082, 0.0)  51.923249  4.469208
# 391          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 397           (52.39479799999999, 4.846481, 0.0)  52.394798  4.846481
# 409          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 414          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 415                  (52.3882436, 4.651775, 0.0)  52.388244  4.651775
# 420  (52.15385509999999, 5.019955299999999, 0.0)  52.153855  5.019955
# 425                 (51.8464418, 4.6782728, 0.0)  51.846442  4.678273
# 426                  (52.3927153, 4.848034, 0.0)  52.392715  4.848034
# 456                 (51.9160421, 4.4795199, 0.0)  51.916042  4.479520
# 472                 (52.3072349, 5.1305166, 0.0)  52.307235  5.130517
# 479         (53.0971039, 6.887815799999999, 0.0)  53.097104  6.887816
# 481          (52.132633, 5.291265999999999, 0.0)  52.132633  5.291266
# 505                 (52.1846466, 6.2112042, 0.0)  52.184647  6.211204
# 509                   (51.480008, 5.421951, 0.0)  51.480008  5.421951
# 510         (51.4570735, 5.396912899999999, 0.0)  51.457073  5.396913
# 528                   (52.220522, 6.889943, 0.0)  52.220522  6.889943
# 538                   (52.360783, 4.893751, 0.0)  52.360783  4.893751
# 544                   (52.343881, 4.846614, 0.0)  52.343881  4.846614
# 560                 (52.0658397, 5.2583797, 0.0)  52.065840  5.258380
# 567                  (51.9163212, 4.475754, 0.0)  51.916321  4.475754
#
#      altitude  cluster
# 9         0.0        3
# 16        0.0        3
# 21        0.0        3
# 39        0.0        2
# 81        0.0        0
# 104       0.0        0
# 117       0.0        2
# 122       0.0        0
# 126       0.0        0
# 134       0.0        0
# 135       0.0        6
# 139       0.0        5
# 155       0.0        0
# 178       0.0        1
# 187       0.0        1
# 213       0.0        3
# 270       0.0        5
# 272       0.0        0
# 273       0.0        3
# 274       0.0        0
# 280       0.0        3
# 283       0.0        4
# 294       0.0        3
# 305       0.0        3
# 308       0.0        5
# 327       0.0        0
# 334       0.0        3
# 348       0.0        3
# 351       0.0        3
# 352       0.0        3
# 353       0.0        3
# 356       0.0        0
# 364       0.0        0
# 366       0.0        0
# 370       0.0        1
# 371       0.0        0
# 372       0.0        3
# 377       0.0        3
# 386       0.0        0
# 387       0.0        5
# 391       0.0        0
# 397       0.0        3
# 409       0.0        0
# 414       0.0        0
# 415       0.0        3
# 420       0.0        0
# 425       0.0        5
# 426       0.0        3
# 456       0.0        5
# 472       0.0        0
# 479       0.0        2
# 481       0.0        0
# 505       0.0        4
# 509       0.0        1
# 510       0.0        1
# 528       0.0        6
# 538       0.0        3
# 544       0.0        3
# 560       0.0        0
# 567       0.0        5

# %%
# We find the centroid of the cluster located in amsterdam in this case
k_means = KMeans(init="k-means++", n_clusters=7, n_init=25)
k_means.fit(x)
k_means_labels = k_means.labels_
k_means_cluster_centers = k_means.cluster_centers_
k_means_cluster_centers
latitudea = 52.37593
longitudea = 4.86973752 
df1['cluster'].value_counts()
# Out:
# 0    21
# 3    20
# 5     7
# 1     5
# 2     3
# 6     2
# 4     2
# Name: cluster, dtype: int64

# %%
# Map for Netherlands
lat_nl = 52.132633 
long_nl =  5.291266
map_nl = folium.Map(location=[lat_nl, long_nl], zoom_start=7)

##colordict = {'Software': 'blue', 'Media and Entertainment': 'green', 'Environmental Technology': 'white'}
colordict = {0: 'blue', 1: 'green', 2: 'yellow', 3: 'red', 4: 'white', 5: 'orange', 6: 'grey'}

# add markers to map
for lat, lng, label, sector in zip(df1['lat'], df1['lon'], df1['Company name for communication'], df1['cluster']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label, 
        color='black',
        fill=True,
        fill_color=colordict[sector],
        fill_opacity=0.7,
        parse_html=False).add_to(map_nl)    
map_nl
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_aea4ae9f34a247b499bd4063b1be8f0b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_aea4ae9f34a247b499bd4063b1be8f0b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_aea4ae9f34a247b499bd4063b1be8f0b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_aea4ae9f34a247b499bd4063b1be8f0b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B52.132633%2C%205.291266%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### Mapping UK Companies by sector

# %%
## Now that we can see the map we can delete the outlier companies 
df = df[df['Company name for communication'] != 'DJS (UK) Limited']
df = df[df['Company name for communication'] != 'MPB Group Limited']
df = df[df['Company name for communication'] != 'Vizolution']
df = df[df['Company name for communication'] != 'Unify Communications Ltd.']
df = df[df['Company name for communication'] != 'Hutch']
df = df[df['Company name for communication'] != 'Person Centred Software']
df = df[df['Company name for communication'] != 'Peak']
df = df[df['Company name for communication'] != 'Bango']
df = df[df['Company name for communication'] != 'Giacom']
df = df[df['Company name for communication'] != 'SimplyCook']
df = df[df['Company name for communication'] != 'Cloudhouse']

# %%
x = list(zip(df['lon'].values, df['lat'].values))
clustering = AgglomerativeClustering(6).fit(x)
clustering.labels_
df['cluster'] = clustering.labels_
k_means = KMeans(init="k-means++", n_clusters=6, n_init=25)
k_means.fit(x)
k_means_labels = k_means.labels_
k_means_cluster_centers = k_means.cluster_centers_
k_means_cluster_centers
df['cluster'].value_counts()
# Out:
# 4    33
# 1    29
# 2     6
# 0     5
# 5     4
# 3     3
# Name: cluster, dtype: int64

# %%
# We get de coordinates of the cluster of London and Cambridge
k_means_cluster_centers = k_means.cluster_centers_
centroids = pd.DataFrame(k_means_cluster_centers)
latitude = 51.51470127
longitude = -0.10633714
latitudec = 52.23578662
longitudec = 0.1373794

# %%
lat_gb = 54.378051 
long_gb = -3.435973
map_gb = folium.Map(location=[lat_gb, long_gb], zoom_start=6)

colordict = {0: 'blue', 1: 'green', 2: 'yellow', 3: 'red', 4: 'white', 5: 'orange'}
###colordict = {'Software': 'blue', 'Media and Entertainment': 'green', 'Fintech': 'white', 'Hardware': 'red'}

with open('C:/Users/marc/london_boroughs.json') as json_data:
    london = json.load(json_data)
    
folium.GeoJson(
    london,
    name='geojson'
).add_to(map_gb)

# add markers to map
for lat, lng, label, sector in zip(df['lat'], df['lon'], df['Company name for communication'], df['cluster']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label, 
        color='black',
        fill=True,
        fill_color=colordict[sector],
        fill_opacity=0.7,
        parse_html=False).add_to(map_gb)    
map_gb
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e664f43e3c6b4bdd9e7fffc9dc3bba2e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e664f43e3c6b4bdd9e7fffc9dc3bba2e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e664f43e3c6b4bdd9e7fffc9dc3bba2e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e664f43e3c6b4bdd9e7fffc9dc3bba2e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B54.378051%2C%20-3.435973%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ### Foursquare API - UK

# %%
CLIENT_ID = 'UXH3QXWSKIKRCISLRKVKEGCO54GYL3RWVPU3FZ4HCBVDUOBN' # your Foursquare ID
CLIENT_SECRET = 'TSCQVX0CDVXZNLTEQW5X2LHUXQE53A2DRRJ22NJR54RKYHAY' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 50
search_query = 'College & University' ##Nightlife Spot Outdoors & Recreation Shop & Service Travel & Transport Arts & Entertainment
radius = 2000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()

# assign relevant part of JSON to venues
venues = results['response']['venues']

# %%
CLIENT_ID = 'UXH3QXWSKIKRCISLRKVKEGCO54GYL3RWVPU3FZ4HCBVDUOBN' # your Foursquare ID
CLIENT_SECRET = 'TSCQVX0CDVXZNLTEQW5X2LHUXQE53A2DRRJ22NJR54RKYHAY' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
search_query = 'College & University' ##Nightlife Spot Outdoors & Recreation Shop & Service Travel & Transport Arts & Entertainment
radius = 2000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitudec, longitudec, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()

# assign relevant part of JSON to venues
venuesc = results['response']['venues']

# %%
# tranform venues into a dataframe
dataframe = pd.json_normalize(venues)
dataframe.head()

# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered
# Out:
#                                                  name  \
# 0             King's College London - Waterloo Campus
# 1                Royal College of Surgeons of England
# 2               King's College London - Strand Campus
# 3                           University College London
# 4                 Royal College of Emergency Medicine
# 5                         Kings College Student Union
# 6                    King's College NHS Health Centre
# 7           King's College - Language Resource Center
# 8                                  Kensington College
# 9       Royal College of Paediatrics and Child Health
# 10                     Royal College of Anaesthetists
# 11                                       Cats College
# 12     LonDEC, King's College London Dental Institute
# 13        King's College London - Drury Lane Building
# 14                        University College Hospital
# 15                                    Princes College
# 16                              Global London College
# 17                                       College Hall
# 18                 King's College London - Bush House
# 19                              Shakespearean College
# 20                                 Goodenough College
# 21                    London College of Communication
# 22                          Eynsford Language College
# 23                                    College of Arms
# 24                    CCL (College of Central London)
# 25                Kaplan International College London
# 26                          College Of Medicine - KSU
# 27  MRC Laboartory for Molecular Cell Biology, Uni...
# 28                                    Gresham College
# 29                                   Williams College
# 30   King’s College London Bush House-South East Wing
# 31  King’s College London - Bush House North East ...
# 32          London College of Online Learning Limited
# 33                 London College Of Contemporary Art
# 34                    The College, 12 Southampton Row
# 35                      College Of Emergency Medicine
# 36                                   The College Arms
# 37                        st patricks college holborn
# 38                            Goodenough College (LH)
# 39  Centre For Telecommunications Research-king's ...
# 40                     Library Royal College Surgeons
# 41    The Dickson Poon School of Law (King's College)
# 42                          London College of Fashion
# 43                        cafe direct @ kings college
# 44    King's College London - Virginia Woolf Building
# 45              King's College - Geography Department
# 46                        S401 - Kings College London
# 47   Department of War Studies, King's College London
# 48                                      College Green
# 49        Cultural Institute at King's College London
#
#                          categories                              address  \
# 0                        University                          Stamford St
# 1                    Medical School           35-43 Lincoln's Inn Fields
# 2                        University                               Strand
# 3                        University                             Gower St
# 4   College Administrative Building                7-9 Bream's Buildings
# 5                    Student Center                           Surrey St.
# 6                   Doctor's Office                        Surrey Street
# 7             College Arts Building                                  NaN
# 8   College Administrative Building              Wesley Ho, 4 Wild Court
# 9                          Building                    5-11 Theobalds Rd
# 10        College Academic Building                       35 Red Lion Sq
# 11        College Academic Building                 43-45 Bloomsbury Sq.
# 12                   Medical School  3rd Floor Franklin Wilkins Building
# 13                       University                     26-29 Drury Lane
# 14                         Hospital                        235 Euston Rd
# 15                           Office                 36 New Oxford Street
# 16        College Academic Building                     36 New Oxford St
# 17           College Residence Hall                            Malet St.
# 18      College Technology Building                                  NaN
# 19     General College & University                        34 Bloomsbury
# 20                   Student Center                     Mecklenburgh Sq.
# 21            College Arts Building               UAL, Elephant & Castle
# 22     General College & University                                37-39
# 23              Monument / Landmark            130 Queen Victoria Street
# 24     General College & University                                  NaN
# 25     General College & University                         Palace House
# 26                   Medical School                                  NaN
# 27                      Medical Lab                         Gower Street
# 28                       University                   Barnard's Inn Hall
# 29        College Academic Building                                  NaN
# 30     General College & University                                  NaN
# 31        College Academic Building                              Aldwych
# 32           Adult Education Center        Kemp House, 152-160 City Road
# 33     General College & University                                  NaN
# 34        College Academic Building                                  NaN
# 35                   Medical School                                  NaN
# 36                              Pub                      18 Store Street
# 37        College Academic Building                                  NaN
# 38           College Residence Hall                         London House
# 39        College Academic Building                                  NaN
# 40                  College Library                                  NaN
# 41        College Academic Building             Somerset House East Wing
# 42     General College & University                         High holborn
# 43                             Café                                  NaN
# 44        College Academic Building                          22 Kingsway
# 45         College Science Building                           The Strand
# 46      College Technology Building                               Strand
# 47     General College & University              King's Building, Strand
# 48                           Garden                          Abingdon St
# 49                    Movie Theater    Somerset House East Wing - Strand
#
#           lat       lng                                     labeledLatLngs  \
# 0   51.505598 -0.112166  [{'label': 'display', 'lat': 51.50559751070975...
# 1   51.515533 -0.115607  [{'label': 'display', 'lat': 51.51553266542977...
# 2   51.511627 -0.116376  [{'label': 'display', 'lat': 51.5116270804117,...
# 3   51.524395 -0.133593  [{'label': 'display', 'lat': 51.52439526888408...
# 4   51.516114 -0.111225  [{'label': 'display', 'lat': 51.5161143873048,...
# 5   51.511180 -0.115169  [{'label': 'display', 'lat': 51.51117983551853...
# 6   51.511238 -0.114956  [{'label': 'display', 'lat': 51.51123788646011...
# 7   51.511255 -0.115696  [{'label': 'display', 'lat': 51.511255, 'lng':...
# 8   51.515536 -0.119353  [{'label': 'display', 'lat': 51.51553585857806...
# 9   51.520838 -0.115747  [{'label': 'display', 'lat': 51.52083784902094...
# 10  51.519279 -0.119861  [{'label': 'display', 'lat': 51.519278810924, ...
# 11  51.518405 -0.121875  [{'label': 'display', 'lat': 51.51840492661380...
# 12  51.505456 -0.112899  [{'label': 'display', 'lat': 51.50545575971391...
# 13  51.514786 -0.123150  [{'label': 'display', 'lat': 51.5147855725507,...
# 14  51.525004 -0.136339  [{'label': 'display', 'lat': 51.52500442254615...
# 15  51.517160 -0.125418  [{'label': 'display', 'lat': 51.51715977380225...
# 16  51.517237 -0.125606  [{'label': 'display', 'lat': 51.51723656908332...
# 17  51.522250 -0.131133  [{'label': 'display', 'lat': 51.52224975605932...
# 18  51.512600 -0.116931  [{'label': 'display', 'lat': 51.51260002394812...
# 19  51.518298 -0.127844  [{'label': 'display', 'lat': 51.51829804463054...
# 20  51.526110 -0.118912  [{'label': 'display', 'lat': 51.52611049009676...
# 21  51.494837 -0.101476  [{'label': 'display', 'lat': 51.49483667136030...
# 22  51.516189 -0.131796  [{'label': 'display', 'lat': 51.51618893787597...
# 23  51.512007 -0.098475  [{'label': 'display', 'lat': 51.51200696300692...
# 24  51.527130 -0.086530  [{'label': 'display', 'lat': 51.52712964078540...
# 25  51.532738 -0.107333  [{'label': 'display', 'lat': 51.53273828651154...
# 26  51.512803 -0.100416  [{'label': 'display', 'lat': 51.512803, 'lng':...
# 27  51.524280 -0.131795  [{'label': 'display', 'lat': 51.52427960215237...
# 28  51.517685 -0.109794  [{'label': 'display', 'lat': 51.5176848146853,...
# 29  51.517145 -0.105095  [{'label': 'display', 'lat': 51.51714465968388...
# 30  51.512860 -0.116581  [{'label': 'display', 'lat': 51.51286, 'lng': ...
# 31  51.513034 -0.116899  [{'label': 'display', 'lat': 51.513034, 'lng':...
# 32  51.513535 -0.112449  [{'label': 'display', 'lat': 51.51353461974712...
# 33  51.518055 -0.110587  [{'label': 'display', 'lat': 51.518055, 'lng':...
# 34  51.518927 -0.121084  [{'label': 'display', 'lat': 51.518927, 'lng':...
# 35  51.519280 -0.119321  [{'label': 'display', 'lat': 51.5192804875453,...
# 36  51.519854 -0.131830  [{'label': 'display', 'lat': 51.51985384114787...
# 37  51.515123 -0.114950  [{'label': 'display', 'lat': 51.51512322025362...
# 38  51.524426 -0.117504  [{'label': 'display', 'lat': 51.52442569277209...
# 39  51.511780 -0.115796  [{'label': 'display', 'lat': 51.51178, 'lng': ...
# 40  51.515533 -0.115607  [{'label': 'display', 'lat': 51.51553266542977...
# 41  51.511446 -0.116799  [{'label': 'display', 'lat': 51.51144573027518...
# 42  51.517990 -0.116276  [{'label': 'display', 'lat': 51.5179900298046,...
# 43  51.511284 -0.115904  [{'label': 'display', 'lat': 51.5112837912044,...
# 44  51.514260 -0.118053  [{'label': 'display', 'lat': 51.51425994999053...
# 45  51.511693 -0.116130  [{'label': 'display', 'lat': 51.51169341219328...
# 46  51.512446 -0.116207  [{'label': 'display', 'lat': 51.512446, 'lng':...
# 47  51.511924 -0.116468  [{'label': 'display', 'lat': 51.51192379403626...
# 48  51.497900 -0.126122  [{'label': 'display', 'lat': 51.4979000208282,...
# 49  51.511190 -0.116660  [{'label': 'display', 'lat': 51.51119, 'lng': ...
#
#     distance postalCode  cc         city           state         country  \
# 0       1090        SE1  GB       London  Greater London  United Kingdom
# 1        648   WC2A 3PE  GB      Holborn  Greater London  United Kingdom
# 2        775   WC2R 2LS  GB       London  Greater London  United Kingdom
# 3       2174   WC1E 6BT  GB       London  Greater London  United Kingdom
# 4        373   EC4A 1DT  GB       London  Greater London  United Kingdom
# 5        726   WC2R 2LS  GB       London  Greater London  United Kingdom
# 6        710   WC2R 2LS  GB       London  Greater London  United Kingdom
# 7        753        NaN  GB          NaN             NaN  United Kingdom
# 8        906   WC2B 4AU  GB       London  Greater London  United Kingdom
# 9        944   WC1X 8SH  GB       London  Greater London  United Kingdom
# 10      1066   WC1R 4SG  GB       London  Greater London  United Kingdom
# 11      1152   WC1A 2RA  GB       London  Greater London  United Kingdom
# 12      1125    SE1 9NH  GB     Waterloo  Greater London  United Kingdom
# 13      1164   WC2B 5RL  GB       London  Greater London  United Kingdom
# 14      2373    NW1 2BU  GB  Camden Town  Greater London  United Kingdom
# 15      1349   WC1A 1EP  GB       London  Greater London  United Kingdom
# 16      1364   WC1A 1EP  GB       London  Greater London  United Kingdom
# 17      1912   WC1E 7HZ  GB  Camden Town  Greater London  United Kingdom
# 18       770        NaN  GB          NaN             NaN  United Kingdom
# 19      1542        NaN  GB       London  Greater London  United Kingdom
# 20      1540   WC1N 2AN  GB       London  Greater London  United Kingdom
# 21      2236    SE1 6SB  GB       London  Greater London  United Kingdom
# 22      1771        NaN  GB       London  Greater London  United Kingdom
# 23       621   EC4V 4BT  GB       London  Greater London  United Kingdom
# 24      1948        NaN  GB       Лондон             NaN  United Kingdom
# 25      2009    SE1 9DE  GB       London  Greater London  United Kingdom
# 26       461        NaN  GB          NaN             NaN  United Kingdom
# 27      2060   WC1E 6BT  GB       London  Greater London  United Kingdom
# 28       409   EC1N 2HH  GB       London  Greater London  United Kingdom
# 29       285        NaN  GB       London  Greater London  United Kingdom
# 30       738   WC2B 4LL  GB       London  Greater London  United Kingdom
# 31       754   WC2B 4BG  GB       London  Greater London  United Kingdom
# 32       442   EC1V 2NX  GB       London  Greater London  United Kingdom
# 33       475   EC1N 2LL  GB          NaN             NaN  United Kingdom
# 34      1124      W C1B  GB       London  Greater London  United Kingdom
# 35      1033        NaN  GB          NaN             NaN  United Kingdom
# 36      1856   WC1E 7DH  GB       London  Greater London  United Kingdom
# 37       598        NaN  GB          NaN             NaN  United Kingdom
# 38      1330   WC1N 2AB  GB   Bloomsbury  Greater London  United Kingdom
# 39       731        NaN  GB          NaN             NaN  United Kingdom
# 40       648        NaN  GB          NaN             NaN  United Kingdom
# 41       810   WC2R 2LS  GB       London  Greater London  United Kingdom
# 42       779        NaN  GB  Camden Town  Greater London  United Kingdom
# 43       764        NaN  GB          NaN             NaN  United Kingdom
# 44       813      W C2B  GB       London  Greater London  United Kingdom
# 45       756        NaN  GB       London  Greater London  United Kingdom
# 46       728    WC2 R 1  GB       London  Greater London  United Kingdom
# 47       766        NaN  GB       London  Greater London  United Kingdom
# 48      2318    SW1 P 3  GB       London  Greater London  United Kingdom
# 49       814   WC2R 2LS  GB       London  Greater London  United Kingdom
#
#                                      formattedAddress  \
# 0   [Stamford St, London, Greater London,  SE1, Un...
# 1   [35-43 Lincoln's Inn Fields, Holborn, Greater ...
# 2   [Strand (at Surrey St), London, Greater London...
# 3   [Gower St (btwn Gower Pl. & Torrington Pl.), L...
# 4   [7-9 Bream's Buildings, London, Greater London...
# 5   [Surrey St., London, Greater London, WC2R 2LS,...
# 6   [Surrey Street, London, Greater London, WC2R 2...
# 7                                    [United Kingdom]
# 8   [Wesley Ho, 4 Wild Court, London, Greater Lond...
# 9   [5-11 Theobalds Rd, London, Greater London, WC...
# 10  [35 Red Lion Sq, London, Greater London, WC1R ...
# 11  [43-45 Bloomsbury Sq., London, Greater London,...
# 12  [3rd Floor Franklin Wilkins Building (150 Stam...
# 13  [26-29 Drury Lane (Strand Campus), London, Gre...
# 14  [235 Euston Rd (Gower St), Camden Town, Greate...
# 15  [36 New Oxford Street, London, Greater London,...
# 16  [36 New Oxford St, London, Greater London, WC1...
# 17  [Malet St., Camden Town, Greater London, WC1E ...
# 18                                   [United Kingdom]
# 19  [34 Bloomsbury, London, Greater London, United...
# 20  [Mecklenburgh Sq., London, Greater London, WC1...
# 21  [UAL, Elephant & Castle, London, Greater Londo...
# 22  [37-39 (Oxford St.), London, Greater London, U...
# 23  [130 Queen Victoria Street, London, Greater Lo...
# 24                           [Лондон, United Kingdom]
# 25  [Palace House (3 Cathedral Street), London, Gr...
# 26                                   [United Kingdom]
# 27  [Gower Street, Camden, Greater London, WC1E 6B...
# 28  [Barnard's Inn Hall (btwn Fetter Ln. and Furni...
# 29           [London, Greater London, United Kingdom]
# 30  [London, Greater London, WC2B 4LL, United King...
# 31  [Aldwych, London, Greater London, WC2B 4BG, Un...
# 32  [Kemp House, 152-160 City Road (Kemp House, 15...
# 33                         [EC1N 2LL, United Kingdom]
# 34    [London, Greater London, W C1B, United Kingdom]
# 35                                   [United Kingdom]
# 36  [18 Store Street, London, Greater London, WC1E...
# 37                                   [United Kingdom]
# 38  [London House (Mecklenburgh Square), Bloomsbur...
# 39                                   [United Kingdom]
# 40                                   [United Kingdom]
# 41  [Somerset House East Wing, London, Greater Lon...
# 42  [High holborn, Camden Town, Greater London, Un...
# 43                                   [United Kingdom]
# 44  [22 Kingsway, London, Greater London, W C2B, U...
# 45  [The Strand, London, Greater London, United Ki...
# 46  [Strand, London, Greater London, WC2 R 1, Unit...
# 47  [King's Building, Strand, London, Greater Lond...
# 48  [Abingdon St, London, Greater London, SW1 P 3,...
# 49  [Somerset House East Wing - Strand, London, Gr...
#
#                          crossStreet    neighborhood                        id
# 0                                NaN             NaN  4d2351912eb1f04d5c3e07c2
# 1                                NaN             NaN  4c39e0173849c928c7ebc1b1
# 2                       at Surrey St             NaN  4b72fb14f964a520ae932de3
# 3    btwn Gower Pl. & Torrington Pl.             NaN  4b0a52daf964a5203e2323e3
# 4                                NaN             NaN  4e32882a62e12985fd629203
# 5                                NaN             NaN  4bfd26f883bbd13a98ed62c5
# 6                                NaN             NaN  50d1aa74e4b0d3a90c1b4c83
# 7                                NaN             NaN  56af76d438faae8405754445
# 8                                NaN             NaN  4d66271b84f28cfa13b36769
# 9                                NaN             NaN  5000242ae4b0978e430512ba
# 10                               NaN             NaN  4bb09c27f964a520474f3ce3
# 11                               NaN             NaN  4e707015a8098087a01782f8
# 12                   150 Stamford St             NaN  4d7b45026152b60c6c8f7b26
# 13                     Strand Campus             NaN  4cd2a68625ee6dcbb034450f
# 14                          Gower St             NaN  4bfb839cab180f479befb3ce
# 15                               NaN             NaN  4f0d6a8ee4b0e190ab6ac78c
# 16                               NaN             NaN  4f9566fbe4b0b65a8c872028
# 17                               NaN             NaN  4c2af66057a9c9b6db3ff567
# 18                               NaN             NaN  56a64089498ee1e85dc5c194
# 19                               NaN             NaN  5211f5b011d2775a7df60538
# 20                               NaN             NaN  4b3f1bfaf964a52012a425e3
# 21                               NaN             NaN  4b62a4e8f964a520bb4d2ae3
# 22                        Oxford St.             NaN  516556b0e4b068ba321da8a1
# 23                               NaN  City of London  4ac518d0f964a520b5a620e3
# 24                               NaN             NaN  4ec4e9c18b812a2064cba79a
# 25                3 Cathedral Street      Bermondsey  4c32e68b213c2d7fbe1f365d
# 26                               NaN             NaN  534a32bf498e8d936002f2c5
# 27                               NaN             NaN  4d8d22e3b46488bfdafdc5a2
# 28  btwn Fetter Ln. and Furnival St.             NaN  4c18df22fe5a76b033a60215
# 29                               NaN             NaN  4e08b79ed4c03ae0b9d16f5b
# 30                               NaN             NaN  5b47553342d8c2002ce50052
# 31                               NaN             NaN  5a65e791da5ede79a3dd4241
# 32     Kemp House, 152-160 City Road             NaN  619a5a2f52dcb37fe93c2f5a
# 33                               NaN             NaN  5dce75384725c60008380f35
# 34                               NaN             NaN  5be5c8fc67af3a0039b418bb
# 35                               NaN             NaN  4cd7c38ea423a35dd74ce842
# 36                               NaN             NaN  4b588581f964a520e75b28e3
# 37                               NaN             NaN  516e660ee4b042332ac4ad24
# 38               Mecklenburgh Square             NaN  4c18d9c36a21c9b67495c997
# 39                               NaN             NaN  4d7e1340ebc15481772bdba6
# 40                               NaN             NaN  54ec8606498e2e9b20fd7e8f
# 41                               NaN             NaN  51af29d4498e531b0feaf90a
# 42                               NaN             NaN  4c36fcae3849c92859dfbcb1
# 43                               NaN             NaN  5138babbe4b0e0ccc3762214
# 44                               NaN             NaN  522d91ae11d28ed950b94b2a
# 45                               NaN             NaN  4f18028ce4b04c15e6a3322c
# 46                               NaN             NaN  4bebe61c62c0c928669be2d4
# 47                               NaN             NaN  557ee737498e191d3efcb187
# 48                               NaN             NaN  4be99cf3415e20a1310be4bb
# 49                               NaN             NaN  54dad43e498ee7cab71f8e5b

# %%
# tranform venues into a dataframe
dataframe = pd.json_normalize(venuesc)
dataframe.head()

# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filteredc = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filteredc['categories'] = dataframe_filteredc.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filteredc.columns = [column.split('.')[-1] for column in dataframe_filteredc.columns]
dataframe_filteredc
# Out:
#                                        name                    categories  \
# 0          Cambridge Regional College (CRC)                  Trade School
# 1  Cambridge Regional College Sports Centre          Gym / Fitness Center
# 2          LRC @ Cambridge Regional College               College Library
# 3                       College fields park                          Park
# 4          Bellerbys College Campus Library                       Library
# 5                 Impington Village College  General College & University
# 6              Chesterton Community College             Community College
# 7                Christ's College Boathouse          Gym / Fitness Center
#
#              address        lat       lng  \
# 0  Kings Hedges Road  52.235356  0.133982
# 1                NaN  52.234847  0.135380
# 2                NaN  52.235321  0.134482
# 3                NaN  52.225881  0.136987
# 4                NaN  52.225874  0.129697
# 5           New Lane  52.247581  0.116579
# 6      79 Bateson Rd  52.217615  0.122328
# 7                NaN  52.213687  0.125596
#
#                                       labeledLatLngs  distance  cc       city  \
# 0  [{'label': 'display', 'lat': 52.23535619082742...       236  GB  Cambridge
# 1  [{'label': 'display', 'lat': 52.23484676090613...       171  GB        NaN
# 2  [{'label': 'display', 'lat': 52.235321484912, ...       204  GB        NaN
# 3  [{'label': 'display', 'lat': 52.22588075994904...      1103  GB        NaN
# 4  [{'label': 'display', 'lat': 52.225874, 'lng':...      1221  GB  Cambridge
# 5  [{'label': 'display', 'lat': 52.24758057245346...      1932  GB  Impington
# 6  [{'label': 'display', 'lat': 52.21761492302305...      2268  GB  Cambridge
# 7  [{'label': 'display', 'lat': 52.213687, 'lng':...      2587  GB        NaN
#
#             state         country  \
# 0  Cambridgeshire  United Kingdom
# 1             NaN  United Kingdom
# 2             NaN  United Kingdom
# 3             NaN  United Kingdom
# 4  Cambridgeshire  United Kingdom
# 5  Cambridgeshire  United Kingdom
# 6  Cambridgeshire  United Kingdom
# 7             NaN  United Kingdom
#
#                                     formattedAddress postalCode  \
# 0  [Kings Hedges Road, Cambridge, Cambridgeshire,...        NaN
# 1                                   [United Kingdom]        NaN
# 2                                   [United Kingdom]        NaN
# 3                                   [United Kingdom]        NaN
# 4        [Cambridge, Cambridgeshire, United Kingdom]        NaN
# 5  [New Lane, Impington, Cambridgeshire, United K...        NaN
# 6  [79 Bateson Rd, Cambridge, Cambridgeshire, CB4...    CB4 3YN
# 7                                   [United Kingdom]        NaN
#
#                          id
# 0  4c0fca61b93cc9b61cb155e0
# 1  4d93283f9213b1f72551c146
# 2  506ac419e4b014fb398a5e12
# 3  4fc126cde4b0117b73825586
# 4  4eb3f70ae5fa17fc861cf763
# 5  4bf55627cad2c928bee59c99
# 6  4e6e728e2271a8cac03aea5b
# 7  514a13dae4b0a74cdde8bba4

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the centroid of the London cluster

# add a red circle marker to represent the London centroid
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='London Centroid',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Colleges & Universities as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ab580d1df54640a4a6cbc9503e0eab02%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ab580d1df54640a4a6cbc9503e0eab02%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ab580d1df54640a4a6cbc9503e0eab02%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ab580d1df54640a4a6cbc9503e0eab02%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B51.51470127%2C%20-0.10633714%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
venues_map = folium.Map(location=[latitudec, longitudec], zoom_start=13) # generate map centred around the centroid of the Cambridge cluster

# add a red circle marker to represent the Cambridge centroid
folium.features.CircleMarker(
    [latitudec, longitudec],
    radius=10,
    color='green',
    popup='Cambridge Centroid',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Colleges & Universities as blue circle markers
for lat, lng, label in zip(dataframe_filteredc.lat, dataframe_filteredc.lng, dataframe_filteredc.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_8172b996697d43c88411cdc745928ae8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8172b996697d43c88411cdc745928ae8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8172b996697d43c88411cdc745928ae8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_8172b996697d43c88411cdc745928ae8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B52.23578662%2C%200.1373794%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### Foursquare API - Netherlands

# %%
CLIENT_ID = 'UXH3QXWSKIKRCISLRKVKEGCO54GYL3RWVPU3FZ4HCBVDUOBN' # your Foursquare ID
CLIENT_SECRET = 'TSCQVX0CDVXZNLTEQW5X2LHUXQE53A2DRRJ22NJR54RKYHAY' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
search_query = 'College & University' ##Nightlife Spot Outdoors & Recreation Shop & Service Travel & Transport Arts & Entertainment
radius = 2000
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitudea, longitudea, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitudea, longitudea, VERSION, search_query, radius, LIMIT)
results = requests.get(url).json()
# assign relevant part of JSON to venues
venuesa = results['response']['venues']

# %%
# tranform venues into a dataframe
dataframe = pd.json_normalize(venuesa)
dataframe.head()

# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filteredn = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venuea.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filteredn['categories'] = dataframe_filteredn.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filteredn.columns = [column.split('.')[-1] for column in dataframe_filteredn.columns]
dataframe_filteredn
# Out:
#                               name                    categories  \
# 0             College Viva La Vida              Fraternity House
# 1            ALTRA College Centrum                        School
# 2   College Koninklijk Zeemanshoop                    Club House
# 3              College Frat Boys P              Fraternity House
# 4                 Marcanti College             Community College
# 5                College Frat Boys              Fraternity House
# 6              Frat Boys College R              Fraternity House
# 7              Frat Boys College Q              Fraternity House
# 8                          College                    University
# 9                     College-Club                        Office
# 10                   College Hotel                   Music Venue
# 11         Luzac College Amsterdam                        School
# 12                Cannabis College          Marijuana Dispensary
# 13                 Huygens College                   High School
# 14             Leidenhoven College     College Academic Building
# 15              Iedersland College  General College & University
# 16        Flight Attendant College                Student Center
# 17                   Media College         College Arts Building
# 18                   Luzac College                          None
# 19                 Ag bell college                   High School
# 20                   Altra College                   High School
# 21              Orion college West  General College & University
# 22               Collegezaal F0.01             College Classroom
# 23          Mediacollege Amsterdam  General College & University
#
#                             address       crossStreet        lat       lng  \
# 0                  Marnixstraat 229      Westerstraat  52.377743  4.878774
# 1                  Konijnenstraat 7       Hazenstraat  52.371140  4.881770
# 2                      Muntplein 10               NaN  52.366346  4.893132
# 3                  marnixstraat 221      westerstraat  52.376181  4.878048
# 4            Jan van Galenstraat 17               NaN  52.375232  4.865673
# 5                  marnixstraat 226      westerstraat  52.369146  4.876717
# 6                  marnixstraat 223      westerstraat  52.377719  4.878774
# 7                  marnixstraat 225      westerstraat  52.378679  4.878568
# 8                               NaN               NaN  52.385898  4.843427
# 9                   Oudebrugsteeg 9               NaN  52.373844  4.894876
# 10                              NaN               NaN  52.370220  4.895170
# 11             Passeerdersgracht 25               NaN  52.366739  4.880632
# 12      Oudezijds Achterburgwal 124               NaN  52.372140  4.897534
# 13  2e constantijn huygensstraat 31               NaN  52.364408  4.872481
# 14            Roemer Visscherstraat               NaN  52.361042  4.875969
# 15                              NaN               NaN  52.370013  4.844079
# 16                              NaN               NaN  52.365182  4.892201
# 17                   condensatorweg               NaN  52.389748  4.851019
# 18                Prinsengracht 927               NaN  52.362220  4.891351
# 19                Zekeringstraat 45               NaN  52.395968  4.848865
# 20               Stadhouderskade 60  Frans Halsstraat  52.358540  4.888616
# 21                   Zekeringstraat               NaN  52.395957  4.848846
# 22        Kloverniersburgwal (OMHP)               NaN  52.369303  4.896608
# 23                    Contactweg 36               NaN  52.391117  4.856823
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 52.377743, 'lng':...       646    1015 WD
# 1   [{'label': 'display', 'lat': 52.3711399, 'lng'...       976    1016 SL
# 2   [{'label': 'display', 'lat': 52.36634615867874...      1914        NaN
# 3   [{'label': 'display', 'lat': 52.376181, 'lng':...       565     1015wd
# 4   [{'label': 'display', 'lat': 52.37523249608226...       286        NaN
# 5   [{'label': 'display', 'lat': 52.36914636209053...       891     1015wd
# 6   [{'label': 'display', 'lat': 52.37771864999999...       645     1015wd
# 7   [{'label': 'display', 'lat': 52.37867855409016...       673     1015wd
# 8   [{'label': 'display', 'lat': 52.385898, 'lng':...      2104        NaN
# 9   [{'label': 'display', 'lat': 52.37384380423829...      1724    1016 GX
# 10  [{'label': 'display', 'lat': 52.37022, 'lng': ...      1841        NaN
# 11  [{'label': 'display', 'lat': 52.366739, 'lng':...      1262    1016 XG
# 12  [{'label': 'display', 'lat': 52.37213973022122...      1935    1012 DT
# 13  [{'label': 'display', 'lat': 52.3644075066318,...      1296        NaN
# 14  [{'label': 'display', 'lat': 52.361042, 'lng':...      1710    1054 EW
# 15  [{'label': 'display', 'lat': 52.370013, 'lng':...      1864        NaN
# 16  [{'label': 'display', 'lat': 52.365182, 'lng':...      1939        NaN
# 17  [{'label': 'display', 'lat': 52.38974757952646...      1995        NaN
# 18  [{'label': 'display', 'lat': 52.3622204511767,...      2118    1017 KD
# 19  [{'label': 'display', 'lat': 52.39596835311292...      2643        NaN
# 20  [{'label': 'display', 'lat': 52.35854028997932...      2322    1072 AC
# 21  [{'label': 'display', 'lat': 52.39595746539847...      2642        NaN
# 22  [{'label': 'display', 'lat': 52.3693027607959,...      1969        NaN
# 23  [{'label': 'display', 'lat': 52.39111693242768...      1904     1014AN
#
#     cc       city          state    country  \
# 0   NL  Amsterdam  Noord-Holland  Nederland
# 1   NL  Amsterdam  Noord-Holland  Nederland
# 2   NL  Amsterdam  Noord-Holland  Nederland
# 3   NL  Amsterdam  Noord-Holland  Nederland
# 4   NL  Amsterdam  Noord-Holland  Nederland
# 5   NL    Jordaan  Noord-Holland  Nederland
# 6   NL  Amsterdam  Noord-Holland  Nederland
# 7   NL    Jordaan  Noord-Holland  Nederland
# 8   NL        NaN            NaN  Nederland
# 9   NL  Amsterdam  Noord-Holland  Nederland
# 10  NL  Amsterdam  Noord-Holland  Nederland
# 11  NL  Amsterdam  Noord-Holland  Nederland
# 12  NL  Amsterdam           1012  Nederland
# 13  NL  Amsterdam  Noord-Holland  Nederland
# 14  NL  Amsterdam  Noord-Holland  Nederland
# 15  NL        NaN            NaN  Nederland
# 16  NL        NaN            NaN  Nederland
# 17  NL  Amsterdam  Noord-Holland  Nederland
# 18  NL  Amsterdam  Noord-Holland  Nederland
# 19  NL  Amsterdam  Noord-Holland  Nederland
# 20  NL  Amsterdam  Noord-Holland  Nederland
# 21  NL  Amsterdam  Noord-Holland  Nederland
# 22  NL  Amsterdam  Noord-Holland  Nederland
# 23  NL  Amsterdam  Noord-Holland  Nederland
#
#                                      formattedAddress  \
# 0   [Marnixstraat 229 (Westerstraat), 1015 WD Amst...
# 1   [Konijnenstraat 7 (Hazenstraat), 1016 SL Amste...
# 2                [Muntplein 10, Amsterdam, Nederland]
# 3   [marnixstraat 221 (westerstraat), 1015wd Amste...
# 4      [Jan van Galenstraat 17, Amsterdam, Nederland]
# 5   [marnixstraat 226 (westerstraat), 1015wd Jorda...
# 6   [marnixstraat 223 (westerstraat), 1015wd Amste...
# 7   [marnixstraat 225 (westerstraat), 1015wd Jorda...
# 8                                         [Nederland]
# 9     [Oudebrugsteeg 9, 1016 GX Amsterdam, Nederland]
# 10                             [Amsterdam, Nederland]
# 11  [Passeerdersgracht 25, 1016 XG Amsterdam, Nede...
# 12  [Oudezijds Achterburgwal 124, 1012 DT Amsterda...
# 13  [2e constantijn huygensstraat 31, Amsterdam, N...
# 14  [Roemer Visscherstraat, 1054 EW Amsterdam, Ned...
# 15                                        [Nederland]
# 16                                        [Nederland]
# 17             [condensatorweg, Amsterdam, Nederland]
# 18  [Prinsengracht 927, 1017 KD Amsterdam, Nederland]
# 19          [Zekeringstraat 45, Amsterdam, Nederland]
# 20  [Stadhouderskade 60 (Frans Halsstraat), 1072 A...
# 21             [Zekeringstraat, Amsterdam, Nederland]
# 22  [Kloverniersburgwal (OMHP), Amsterdam, Nederland]
# 23       [Contactweg 36, 1014AN Amsterdam, Nederland]
#
#                           id
# 0   4d0f2a16b765224b593be332
# 1   4d791e0371a68cfa16411186
# 2   5454b32f498ea36c77e07a52
# 3   4d0f3adbe236548177a570ea
# 4   4ad9b0aaf964a5206d1a21e3
# 5   4d0f2ac8d467236a4bafbc4a
# 6   4d0f2e65c3dc3704bcfd3074
# 7   4d0f2b306331a093d05e4f94
# 8   503db674e4b06abc4a39ee25
# 9   52460c932fc63e75960fac87
# 10  6189cfe6f642c66dcc514b0e
# 11  5dc29a3cc6ee7a00082d714e
# 12  4c193bb59990d13acb327c17
# 13  4c0baa66009a0f47a25febbf
# 14  5acf3db632b61d325c0fa405
# 15  50ee712de4b01c4a89553c69
# 16  4d5925881d6cf04d330134fe
# 17  4dcd05ecd22deadedd2de2bd
# 18  4b6a7cccf964a52098d62be3
# 19  4e65bbe6aeb7360316510601
# 20  4babc386f964a5207ac73ae3
# 21  4edc78cb722e1da304b6f176
# 22  4d468c6e0349224be9be0e4f
# 23  4b62c3f7f964a520c7512ae3

# %%
venues_map = folium.Map(location=[latitudea, longitudea], zoom_start=13) # generate map centred around the centroid of the Amsterdam cluster

# add a red circle marker to represent the Amsterdam centroid
folium.features.CircleMarker(
    [latitudea, longitudea],
    radius=10,
    color='red',
    popup='Amsterdam centroid',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Colleges & Universities as blue circle markers
for lat, lng, label in zip(dataframe_filteredn.lat, dataframe_filteredn.lng, dataframe_filteredn.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4c10e54eec6643bda1cd62d9dcb8090a%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4c10e54eec6643bda1cd62d9dcb8090a%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4c10e54eec6643bda1cd62d9dcb8090a%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4c10e54eec6643bda1cd62d9dcb8090a%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B52.37593%2C%204.86973752%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# ##  Analysis <a name="analysis"></a>

# %%
dataframe_filtered.drop(columns=['id', 'state', 'labeledLatLngs', 'postalCode', 'formattedAddress', 'address',
                                 'crossStreet', 'neighborhood', 'cc', 'lng', 'lat', 'city'])
# Out:
#                                                  name  \
# 0             King's College London - Waterloo Campus
# 1                Royal College of Surgeons of England
# 2               King's College London - Strand Campus
# 3                           University College London
# 4                 Royal College of Emergency Medicine
# 5                         Kings College Student Union
# 6                    King's College NHS Health Centre
# 7           King's College - Language Resource Center
# 8                                  Kensington College
# 9       Royal College of Paediatrics and Child Health
# 10                     Royal College of Anaesthetists
# 11                                       Cats College
# 12     LonDEC, King's College London Dental Institute
# 13        King's College London - Drury Lane Building
# 14                        University College Hospital
# 15                                    Princes College
# 16                              Global London College
# 17                                       College Hall
# 18                 King's College London - Bush House
# 19                              Shakespearean College
# 20                                 Goodenough College
# 21                    London College of Communication
# 22                          Eynsford Language College
# 23                                    College of Arms
# 24                    CCL (College of Central London)
# 25                Kaplan International College London
# 26                          College Of Medicine - KSU
# 27  MRC Laboartory for Molecular Cell Biology, Uni...
# 28                                    Gresham College
# 29                                   Williams College
# 30   King’s College London Bush House-South East Wing
# 31  King’s College London - Bush House North East ...
# 32          London College of Online Learning Limited
# 33                 London College Of Contemporary Art
# 34                    The College, 12 Southampton Row
# 35                      College Of Emergency Medicine
# 36                                   The College Arms
# 37                        st patricks college holborn
# 38                            Goodenough College (LH)
# 39  Centre For Telecommunications Research-king's ...
# 40                     Library Royal College Surgeons
# 41    The Dickson Poon School of Law (King's College)
# 42                          London College of Fashion
# 43                        cafe direct @ kings college
# 44    King's College London - Virginia Woolf Building
# 45              King's College - Geography Department
# 46                        S401 - Kings College London
# 47   Department of War Studies, King's College London
# 48                                      College Green
# 49        Cultural Institute at King's College London
#
#                          categories  distance         country
# 0                        University      1090  United Kingdom
# 1                    Medical School       648  United Kingdom
# 2                        University       775  United Kingdom
# 3                        University      2174  United Kingdom
# 4   College Administrative Building       373  United Kingdom
# 5                    Student Center       726  United Kingdom
# 6                   Doctor's Office       710  United Kingdom
# 7             College Arts Building       753  United Kingdom
# 8   College Administrative Building       906  United Kingdom
# 9                          Building       944  United Kingdom
# 10        College Academic Building      1066  United Kingdom
# 11        College Academic Building      1152  United Kingdom
# 12                   Medical School      1125  United Kingdom
# 13                       University      1164  United Kingdom
# 14                         Hospital      2373  United Kingdom
# 15                           Office      1349  United Kingdom
# 16        College Academic Building      1364  United Kingdom
# 17           College Residence Hall      1912  United Kingdom
# 18      College Technology Building       770  United Kingdom
# 19     General College & University      1542  United Kingdom
# 20                   Student Center      1540  United Kingdom
# 21            College Arts Building      2236  United Kingdom
# 22     General College & University      1771  United Kingdom
# 23              Monument / Landmark       621  United Kingdom
# 24     General College & University      1948  United Kingdom
# 25     General College & University      2009  United Kingdom
# 26                   Medical School       461  United Kingdom
# 27                      Medical Lab      2060  United Kingdom
# 28                       University       409  United Kingdom
# 29        College Academic Building       285  United Kingdom
# 30     General College & University       738  United Kingdom
# 31        College Academic Building       754  United Kingdom
# 32           Adult Education Center       442  United Kingdom
# 33     General College & University       475  United Kingdom
# 34        College Academic Building      1124  United Kingdom
# 35                   Medical School      1033  United Kingdom
# 36                              Pub      1856  United Kingdom
# 37        College Academic Building       598  United Kingdom
# 38           College Residence Hall      1330  United Kingdom
# 39        College Academic Building       731  United Kingdom
# 40                  College Library       648  United Kingdom
# 41        College Academic Building       810  United Kingdom
# 42     General College & University       779  United Kingdom
# 43                             Café       764  United Kingdom
# 44        College Academic Building       813  United Kingdom
# 45         College Science Building       756  United Kingdom
# 46      College Technology Building       728  United Kingdom
# 47     General College & University       766  United Kingdom
# 48                           Garden      2318  United Kingdom
# 49                    Movie Theater       814  United Kingdom

# %%
dataframe_filteredc.drop(columns=['id', 'state', 'labeledLatLngs', 'postalCode', 'formattedAddress', 'address', 
                                  'cc', 'lng', 'lat', 'city'])
# Out:
#                                        name                    categories  \
# 0          Cambridge Regional College (CRC)                  Trade School
# 1  Cambridge Regional College Sports Centre          Gym / Fitness Center
# 2          LRC @ Cambridge Regional College               College Library
# 3                       College fields park                          Park
# 4          Bellerbys College Campus Library                       Library
# 5                 Impington Village College  General College & University
# 6              Chesterton Community College             Community College
# 7                Christ's College Boathouse          Gym / Fitness Center
#
#    distance         country
# 0       236  United Kingdom
# 1       171  United Kingdom
# 2       204  United Kingdom
# 3      1103  United Kingdom
# 4      1221  United Kingdom
# 5      1932  United Kingdom
# 6      2268  United Kingdom
# 7      2587  United Kingdom

# %%
dataframe_filteredn.drop(columns=['id', 'state', 'labeledLatLngs', 'postalCode', 'formattedAddress', 'address',
                                 'crossStreet', 'cc', 'lng', 'lat', 'city'])
# Out:
#                               name                    categories  distance  \
# 0             College Viva La Vida              Fraternity House       646
# 1            ALTRA College Centrum                        School       976
# 2   College Koninklijk Zeemanshoop                    Club House      1914
# 3              College Frat Boys P              Fraternity House       565
# 4                 Marcanti College             Community College       286
# 5                College Frat Boys              Fraternity House       891
# 6              Frat Boys College R              Fraternity House       645
# 7              Frat Boys College Q              Fraternity House       673
# 8                          College                    University      2104
# 9                     College-Club                        Office      1724
# 10                   College Hotel                   Music Venue      1841
# 11         Luzac College Amsterdam                        School      1262
# 12                Cannabis College          Marijuana Dispensary      1935
# 13                 Huygens College                   High School      1296
# 14             Leidenhoven College     College Academic Building      1710
# 15              Iedersland College  General College & University      1864
# 16        Flight Attendant College                Student Center      1939
# 17                   Media College         College Arts Building      1995
# 18                   Luzac College                          None      2118
# 19                 Ag bell college                   High School      2643
# 20                   Altra College                   High School      2322
# 21              Orion college West  General College & University      2642
# 22               Collegezaal F0.01             College Classroom      1969
# 23          Mediacollege Amsterdam  General College & University      1904
#
#       country
# 0   Nederland
# 1   Nederland
# 2   Nederland
# 3   Nederland
# 4   Nederland
# 5   Nederland
# 6   Nederland
# 7   Nederland
# 8   Nederland
# 9   Nederland
# 10  Nederland
# 11  Nederland
# 12  Nederland
# 13  Nederland
# 14  Nederland
# 15  Nederland
# 16  Nederland
# 17  Nederland
# 18  Nederland
# 19  Nederland
# 20  Nederland
# 21  Nederland
# 22  Nederland
# 23  Nederland

# %% [markdown]
# As we can see trough the multiple maps and now this dataframes, the number of college and univirsities ara significatively high per number of companies on the list, being aware that we have a radius of 2km. Not many places in Europe have around 40 or more venues related with those parameters within 2km. Visualize the data in this case is difficult due to the fact that the size of the DataFrames are different and even being easy to do so, we do not count with many more information as restaurant and others due to the limited number of calls that we can do with Foursquare API.

# %% [markdown]
# ## Results <a name="results"></a>

# %% [markdown]
# After all the process done, we can determine visually a clear correlation between the location and the suceess of that companies. Trough the agglomerative clusters of GB, we can appreciate clearly the distribution and the nucleus of these.
# In Scotland the cluster is defined with Glasgow and Edinbourgh, in London is cristal clear the agglomeration, separatedly but with a similar distribution we have two clusters more, in Cambridge and Oxford respectively and then we have two clusters with a interesting composition. We can see with less agglomeration, the nucleus in Manchester but having companies in Liverpool too and last but not least we see a distribution following almost vertically the cities of Leeds, Sheffield, Nottingham, Derby and Birmingham. In the last cluster it would be really interesting check the communication facilites in the arounds because it seems to follow another sort of pattern than the other clusters with a relative proximity in the same cluster but clearly communicated by a central highway.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# In a exercice of self criticism I would say that I tried to extract conclusions of a subject that is for more experimented programers and data scientists, as I spend barely two month by now learning Python. The remarkable interest of this subject is anyway worth trying because many times we see a extremely close scope on our disciplines and we totally lose the perspective of the problems to solve. In this case, we can try hundreds of ways to determine why a company is succesful, checking their market cap, revenues and as much financial terms as you want, but seeing a relation in what we would not spend time thinking about as the location of this companies is sometimes awakening. It has been spending time researching for and interesting topic that I have discovered what it is the Economy of agglomerations and the benefits of this discipline.
